# %% [markdown]
# # Setup

# %% [markdown]
# Important: before running this notebook, make sure you have the following directories in your Drive:
# - MyDrive/understanding_federated_learning_project/
# - MyDrive/understanding_federated_learning_project/fedmd_collaboration_results_1000.0/
# - MyDrive/understanding_federated_learning_project/fedmd_collaboration_results_0.0/

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install required libraries

# %%
# !pip3 install 'torch'
# !pip3 install 'torchvision'
# !pip3 install 'pillow'
# !pip3 install 'tqdm'
# !pip3 install 'matplotlib'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.0+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (16.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0->torchvision) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Clone the GitHub repository

# %%
import os

if not os.path.isdir('fedmd'):
  # !git clone https://github.com/sergiuabed/fedmd
  # %cd fedmd/
  # !git checkout experiment
  # %cd ..
else:
  # %cd fedmd/
  # !git pull origin
  # %cd ..

if not os.path.isdir('fedmd/baselines_public_cifar10'):
  # !mkdir fedmd/baselines_public_cifar10
# Out:
# Cloning into 'fedmd'...
# remote: Enumerating objects: 2815, done.
# remote: Total 2815 (delta 0), reused 0 (delta 0), pack-reused 2815
# Receiving objects: 100% (2815/2815), 492.95 MiB | 29.90 MiB/s, done.
# Resolving deltas: 100% (823/823), done.
# /content/fedmd
# Updating files: 100% (816/816), done.
# Branch 'experiment' set up to track remote branch 'experiment' from 'origin'.
# Switched to a new branch 'experiment'
# /content

# %% [markdown]
# ## Import libraries

# %%
from fedmd.models_implementations.resnet import ResNet
from fedmd.models_implementations.densenet import DenseNet
from fedmd.models_implementations.shufflenetv2 import ShuffleNetV2
from fedmd.models_implementations.utils import model_size, plot_stats
from fedmd.models_implementations.train_on_cifar import train_on_cifar
from fedmd.data_utils import read_data_splits
from fedmd.client.private_dataloader import ClientPrivateDataset
from torch.utils.data import DataLoader
from fedmd.client.client import Client

# %% [markdown]
# ## Load CIFAR100 locally

# %%
# %cd fedmd/data
# !chmod +x setup_datasets.sh
# !./setup_datasets.sh
# %cd ../..
# Out:
# /content/fedmd/data
# Downloading CIFAR100...
# --2023-05-15 17:22:58--  https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169001437 (161M) [application/x-gzip]
# Saving to: ‘cifar-100-python.tar.gz’
#
# cifar-100-python.ta 100%[===================>] 161.17M  84.3MB/s    in 1.9s
#
# 2023-05-15 17:23:00 (84.3 MB/s) - ‘cifar-100-python.tar.gz’ saved [169001437/169001437]
#
# cifar-100-python/
# cifar-100-python/file.txt~
# cifar-100-python/train
# cifar-100-python/test
# cifar-100-python/meta
# Extracting images for pickle files...
# #### Setting up CIFAR100 ####
# Saving train images...
# 50000it [00:27, 1806.84it/s]
# Saving test images...
# 10000it [00:06, 1596.74it/s]
# /content

# %% [markdown]
# ## Define hyperparameters
# This cell defines the hyperparameters for each architecture

# %%
LR = 1e-1     
MOMENTUM = 0.9       
WEIGHT_DECAY = 1e-4  
NUM_EPOCHS = 30
NUM_CLASSES = 100
GROUPS = 2

######################
ALPHA = 1000.00 #0.00
######################

#ResNet
LAYERS = [3, 3, 3]
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/resnet20'

#DenseNet
K = 12
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/densenet'

#ShuffleNet
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/shufflenetv2'
STAGES_REPEATS_BIG = [4, 8, 4]
STAGES_OUT_CHANNELS_BIG = [32, 64, 128, 256, 512]
STAGES_REPEATS_SMALL = [2, 4, 2]
STAGES_OUT_CHANNELS_SMALL = [16, 32, 64, 128, 256]

RESNET20_BN_PARAMS = [LAYERS, NUM_CLASSES] #net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES)
RESNET20_GN_PARAMS = [LAYERS, NUM_CLASSES, "gn", GROUPS] #net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES, norm_layer="gn", groups=GROUPS)

DENSENET10_PARAMS = [K, 10, 1, NUM_CLASSES, False, GROUPS]  #net = DenseNet(K, 10, 1, NUM_CLASSES, False, GROUPS)
DENSENET20_PARAMS = [K, 20, 1, NUM_CLASSES, False, GROUPS]  #net = DenseNet(K, 20, 1, NUM_CLASSES, False, GROUPS)

SHUFFLENET_BIG = [STAGES_REPEATS_BIG, STAGES_OUT_CHANNELS_BIG, NUM_CLASSES, GROUPS] #net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)
SHUFFLENET_SMALL = [STAGES_REPEATS_SMALL, STAGES_OUT_CHANNELS_SMALL, NUM_CLASSES, GROUPS] #net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)

#architectures = ["/resnet20/resnet20_bn", "/resnet20/resnet20_gn", "/densenet/densenet10", "/densenet/densenet20", "/shufflenetv2/shufflenetbig", "/shufflenetv2/shufflenetsmall"]

archs_dir = {}
archs_dir["/resnet20/resnet20_bn"] = (ResNet, RESNET20_BN_PARAMS)
archs_dir["/resnet20/resnet20_gn"] = (ResNet, RESNET20_GN_PARAMS)
archs_dir["/densenet/densenet10"] = (DenseNet, DENSENET10_PARAMS)
archs_dir["/densenet/densenet20"] = (DenseNet, DENSENET20_PARAMS)
archs_dir["/shufflenetv2/shufflenetbig"] = (ShuffleNetV2, SHUFFLENET_BIG)
archs_dir["/shufflenetv2/shufflenetsmall"] = (ShuffleNetV2, SHUFFLENET_SMALL)

# %%
from fedmd.models_implementations.train_on_cifar import _training, _data_processing
from fedmd.client.private_dataloader import ClientPrivateDataset
from fedmd.data_utils import read_data_splits
from torchvision.datasets import CIFAR10, CIFAR100
from torchvision import transforms

BATCH_SIZE = 128
NUM_WORKERS = 1

#public_train_dataloader, public_validation_dataloader, public_test_dataloader = _data_processing(CIFAR10) # only "public_train_set" is used at this stage of the project

public_train_transform = transforms.Compose(
    [
        transforms.ToTensor(),  # Turn PIL Image to torch.Tensor
        transforms.Normalize(
            (0.485, 0.456, 0.406), (0.229, 0.224, 0.225)
        ),  # Normalizes tensor with mean and standard deviation
    ]
)
public_train_dataset = CIFAR10(root=".", train=True, transform=public_train_transform, download=True)
public_train_dataloader = DataLoader(public_train_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, drop_last=True)

PRIVATE_TRAIN_DATA_DIR = os.path.join('.', 'fedmd', 'data', 'cifar100', 'data', 'train') # location of json files storing the data splits
PRIVATE_TEST_DATA_DIR = os.path.join('.', 'fedmd', 'data', 'cifar100', 'data', 'test')

client_ids, train_data, test_data = read_data_splits(PRIVATE_TRAIN_DATA_DIR, PRIVATE_TEST_DATA_DIR, ALPHA)
# train_clients: list of client ids 
# train_data: dictionary with key=client_id and value=(dictionary storing the data of the client)
# test_data: dictionary storing the data for validation. It is not a dictionary of dictionaries

private_test_dataset = CIFAR100(root=".", train=True, transform=public_train_transform, download=True)   # the same test dataset for all clients
private_test_dataloader = DataLoader(private_test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

LOAD_CHECKPOINTS_FROM_PAST_ROUNDS = False
last_round_performed = -1
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 90860903.52it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:01<00:00, 95730697.08it/s]
# Extracting ./cifar-100-python.tar.gz to .

# %% [markdown]
# ## IMPORTANT: RUN THE FOLLOWING CELL ONLY IF YOU HAVE CHECKPOINTS FROM PREVIOUS ROUND EXECUTIONS STORED IN GOOGLE DRIVE. IF THIS IS THE FIRST TIME YOU RUN THIS NOTEBOOK, SKIP THIS CELL.

# %%
if not os.path.isdir('fedmd_results'):
  LOAD_CHECKPOINTS_FROM_PAST_ROUNDS = True

  last_round_performed = 5 # change this variable to the latest round you have ran and saved on your google drive
  drive_path = f"/content/drive/MyDrive/understanding_federated_learning_project/fedmd_collaboration_results_{ALPHA}/fedmd_results_round{last_round_performed}.zip"
  # !unzip {drive_path} -d .
  # !mv ./content/fedmd_results .
  # !rmdir ./content
# Out:
# Archive:  /content/drive/MyDrive/understanding_federated_learning_project/fedmd_collaboration_results_0.0/fedmd_results_round5.zip
#    creating: ./content/fedmd_results/
#    creating: ./content/fedmd_results/client92/
#   inflating: ./content/fedmd_results/client92/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client92/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client92/stats_0.0.csv
#    creating: ./content/fedmd_results/client54/
#    creating: ./content/fedmd_results/client62/
#    creating: ./content/fedmd_results/client81/
#   inflating: ./content/fedmd_results/client81/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client81/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client81/stats_0.0.csv
#    creating: ./content/fedmd_results/client15/
#    creating: ./content/fedmd_results/client60/
#   inflating: ./content/fedmd_results/client60/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client60/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client60/stats_0.0.csv
#    creating: ./content/fedmd_results/client42/
#    creating: ./content/fedmd_results/client66/
#    creating: ./content/fedmd_results/client8/
#    creating: ./content/fedmd_results/client99/
#   inflating: ./content/fedmd_results/client99/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client99/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client99/stats_0.0.csv
#    creating: ./content/fedmd_results/client7/
#   inflating: ./content/fedmd_results/client7/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client7/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client7/stats_0.0.csv
#    creating: ./content/fedmd_results/client38/
#    creating: ./content/fedmd_results/client84/
#   inflating: ./content/fedmd_results/client84/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client84/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client84/stats_0.0.csv
#    creating: ./content/fedmd_results/client96/
#    creating: ./content/fedmd_results/client27/
#   inflating: ./content/fedmd_results/client27/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client27/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client27/stats_0.0.csv
#    creating: ./content/fedmd_results/client80/
#   inflating: ./content/fedmd_results/client80/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client80/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client80/stats_0.0.csv
#    creating: ./content/fedmd_results/client97/
#   inflating: ./content/fedmd_results/client97/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client97/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client97/stats_0.0.csv
#    creating: ./content/fedmd_results/client98/
#    creating: ./content/fedmd_results/client53/
#    creating: ./content/fedmd_results/client20/
#   inflating: ./content/fedmd_results/client20/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client20/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client20/stats_0.0.csv
#    creating: ./content/fedmd_results/client88/
#   inflating: ./content/fedmd_results/client88/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client88/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client88/stats_0.0.csv
#    creating: ./content/fedmd_results/client16/
#   inflating: ./content/fedmd_results/client16/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client16/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client16/stats_0.0.csv
#    creating: ./content/fedmd_results/client12/
#    creating: ./content/fedmd_results/client67/
#    creating: ./content/fedmd_results/client19/
#    creating: ./content/fedmd_results/client2/
#    creating: ./content/fedmd_results/client17/
#   inflating: ./content/fedmd_results/client17/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client17/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client17/stats_0.0.csv
#    creating: ./content/fedmd_results/client18/
#   inflating: ./content/fedmd_results/client18/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client18/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client18/stats_0.0.csv
#    creating: ./content/fedmd_results/client5/
#   inflating: ./content/fedmd_results/client5/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client5/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client5/stats_0.0.csv
#    creating: ./content/fedmd_results/client0/
#    creating: ./content/fedmd_results/client56/
#   inflating: ./content/fedmd_results/client56/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client56/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client56/stats_0.0.csv
#    creating: ./content/fedmd_results/client95/
#   inflating: ./content/fedmd_results/client95/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client95/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client95/stats_0.0.csv
#    creating: ./content/fedmd_results/client40/
#   inflating: ./content/fedmd_results/client40/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client40/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client40/stats_0.0.csv
#    creating: ./content/fedmd_results/client50/
#   inflating: ./content/fedmd_results/client50/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client50/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client50/stats_0.0.csv
#    creating: ./content/fedmd_results/client55/
#   inflating: ./content/fedmd_results/client55/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client55/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client55/stats_0.0.csv
#    creating: ./content/fedmd_results/client90/
#    creating: ./content/fedmd_results/client58/
#    creating: ./content/fedmd_results/client6/
#    creating: ./content/fedmd_results/client86/
#   inflating: ./content/fedmd_results/client86/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client86/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client86/stats_0.0.csv
#    creating: ./content/fedmd_results/client65/
#    creating: ./content/fedmd_results/client52/
#   inflating: ./content/fedmd_results/client52/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client52/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client52/stats_0.0.csv
#    creating: ./content/fedmd_results/client59/
#    creating: ./content/fedmd_results/client22/
#   inflating: ./content/fedmd_results/client22/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client22/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client22/stats_0.0.csv
#    creating: ./content/fedmd_results/client26/
#   inflating: ./content/fedmd_results/client26/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client26/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client26/stats_0.0.csv
#    creating: ./content/fedmd_results/client25/
#   inflating: ./content/fedmd_results/client25/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client25/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client25/stats_0.0.csv
#    creating: ./content/fedmd_results/client34/
#    creating: ./content/fedmd_results/client89/
#   inflating: ./content/fedmd_results/client89/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client89/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client89/stats_0.0.csv
#    creating: ./content/fedmd_results/client57/
#   inflating: ./content/fedmd_results/client57/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client57/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client57/stats_0.0.csv
#    creating: ./content/fedmd_results/client32/
#    creating: ./content/fedmd_results/client31/
#   inflating: ./content/fedmd_results/client31/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client31/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client31/stats_0.0.csv
#    creating: ./content/fedmd_results/client69/
#    creating: ./content/fedmd_results/client47/
#    creating: ./content/fedmd_results/client33/
#    creating: ./content/fedmd_results/client51/
#    creating: ./content/fedmd_results/client82/
#   inflating: ./content/fedmd_results/client82/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client82/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client82/stats_0.0.csv
#    creating: ./content/fedmd_results/client83/
#    creating: ./content/fedmd_results/client35/
#    creating: ./content/fedmd_results/client64/
#    creating: ./content/fedmd_results/client71/
#   inflating: ./content/fedmd_results/client71/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client71/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client71/stats_0.0.csv
#    creating: ./content/fedmd_results/client37/
#   inflating: ./content/fedmd_results/client37/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client37/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client37/stats_0.0.csv
#    creating: ./content/fedmd_results/client13/
#    creating: ./content/fedmd_results/client79/
#    creating: ./content/fedmd_results/client72/
#   inflating: ./content/fedmd_results/client72/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client72/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client72/stats_0.0.csv
#    creating: ./content/fedmd_results/client45/
#   inflating: ./content/fedmd_results/client45/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client45/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client45/stats_0.0.csv
#    creating: ./content/fedmd_results/client24/
#    creating: ./content/fedmd_results/client87/
#   inflating: ./content/fedmd_results/client87/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client87/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client87/stats_0.0.csv
#    creating: ./content/fedmd_results/client23/
#   inflating: ./content/fedmd_results/client23/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client23/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client23/stats_0.0.csv
#    creating: ./content/fedmd_results/client70/
#   inflating: ./content/fedmd_results/client70/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client70/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client70/stats_0.0.csv
#    creating: ./content/fedmd_results/client43/
#   inflating: ./content/fedmd_results/client43/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client43/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client43/stats_0.0.csv
#    creating: ./content/fedmd_results/client68/
#    creating: ./content/fedmd_results/client75/
#   inflating: ./content/fedmd_results/client75/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client75/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client75/stats_0.0.csv
#    creating: ./content/fedmd_results/client9/
#    creating: ./content/fedmd_results/client91/
#    creating: ./content/fedmd_results/client1/
#   inflating: ./content/fedmd_results/client1/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client1/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client1/stats_0.0.csv
#    creating: ./content/fedmd_results/client30/
#   inflating: ./content/fedmd_results/client30/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client30/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client30/stats_0.0.csv
#    creating: ./content/fedmd_results/client74/
#   inflating: ./content/fedmd_results/client74/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client74/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client74/stats_0.0.csv
#    creating: ./content/fedmd_results/client77/
#    creating: ./content/fedmd_results/client28/
#    creating: ./content/fedmd_results/client11/
#    creating: ./content/fedmd_results/client85/
#   inflating: ./content/fedmd_results/client85/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client85/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client85/stats_0.0.csv
#    creating: ./content/fedmd_results/client46/
#   inflating: ./content/fedmd_results/client46/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client46/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client46/stats_0.0.csv
#    creating: ./content/fedmd_results/client49/
#    creating: ./content/fedmd_results/client10/
#    creating: ./content/fedmd_results/client14/
#    creating: ./content/fedmd_results/client73/
#   inflating: ./content/fedmd_results/client73/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client73/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client73/stats_0.0.csv
#    creating: ./content/fedmd_results/client48/
#    creating: ./content/fedmd_results/client41/
#    creating: ./content/fedmd_results/client78/
#    creating: ./content/fedmd_results/client94/
#   inflating: ./content/fedmd_results/client94/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client94/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client94/stats_0.0.csv
#    creating: ./content/fedmd_results/client21/
#    creating: ./content/fedmd_results/client93/
#    creating: ./content/fedmd_results/client4/
#    creating: ./content/fedmd_results/client63/
#   inflating: ./content/fedmd_results/client63/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client63/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client63/stats_0.0.csv
#    creating: ./content/fedmd_results/client61/
#    creating: ./content/fedmd_results/client76/
#   inflating: ./content/fedmd_results/client76/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client76/checkpoint_0.0.pth
#   inflating: ./content/fedmd_results/client76/stats_0.0.csv
#    creating: ./content/fedmd_results/client3/
#    creating: ./content/fedmd_results/client44/
#    creating: ./content/fedmd_results/client36/
#    creating: ./content/fedmd_results/client29/
#   inflating: ./content/fedmd_results/client29/best_model_0.0.pth
#   inflating: ./content/fedmd_results/client29/checkpoint_0.0.pth
#  extracting: ./content/fedmd_results/client29/stats_0.0.csv
#    creating: ./content/fedmd_results/client39/

# %% [markdown]
# ## Create clients
# Clients are created based on the informtation in:
#   - "fedmd/client/client_architectures.csv" (which contains entries of the form "client_id,architecture")
#   - "fedmd/independent_train" (which stores checkpoints of the models for each client. These checkpoints are obtained after training on both public and private datasets)
#
# note: If you ran this notebook before for one or more rounds, you can load the backup stored on google drive to continue the execution from where you stopped

# %%
import csv
import torch.nn as nn
from fedmd.models_implementations.utils import load_model
from fedmd.client.client import Client

filename ="fedmd/client/client_architectures.csv"
# this csv has records with attributes "client_id"(0,1,2,3,...) and "architecture" (the keys used in "archs_dir" above)

client_archs = {} #key=client_id, val=model instance
clients = []
with open(filename,'r') as data:
  for line in csv.reader(data):
    if line[0] != 'client_id':
      client_id = str(line[0])
      architecture = line[1]
      
      net_class = archs_dir[architecture][0]
      params = archs_dir[architecture][1]

      # instantiate model for the client
      model = net_class(*params)

      # load parameters of best model on the public dataset (CIFAR10) + private dataset (subset of CIFAR100)
      #data = load_model('fedmd/independent_train/client'+str(client_id)+'/best_model_'+str(ALPHA)+'.pth')

      if LOAD_CHECKPOINTS_FROM_PAST_ROUNDS is True and os.path.exists('fedmd_results/client'+str(client_id)+'/checkpoint_'+str(ALPHA)+'.pth'):
        #load checkpoint from previous FedMD executions
        data = load_model('fedmd_results/client'+str(client_id)+'/checkpoint_'+str(ALPHA)+'.pth')
      else:
        #load checkpoint from trainings done only on public and private datasets, i.e. before any collaborative training
        data = load_model('fedmd/independent_train_'+str(ALPHA)+'/client'+str(client_id)+'/checkpoint_'+str(ALPHA)+'.pth')
        #data = load_model('fedmd/independent_train_'+str(ALPHA)+'_v2'+'/client'+str(client_id)+'/checkpoint_'+str(ALPHA)+'.pth')

      weights = data['weights']
      model.load_state_dict(weights)

      private_train_dataset = ClientPrivateDataset(train_data[client_id], train=True)
      private_train_dataloader = DataLoader(private_train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)# , drop_last=True)

      new_client = Client(client_id, public_train_dataloader, private_train_dataloader, private_test_dataloader, None, model, architecture, "cuda")
      clients.append(new_client)

# %%
import csv
import os

clients_accuracies = {}
if LOAD_CHECKPOINTS_FROM_PAST_ROUNDS is True:
  for cl_id in range(0, 100):
    if os.path.exists(f"fedmd_results/client{cl_id}/stats_{ALPHA}.csv"):
      with open(f"fedmd_results/client{cl_id}/stats_{ALPHA}.csv",'r') as data:
        accuracies = [float(line[1]) for line in csv.reader(data) if line[0] != "round"]
        clients_accuracies[str(cl_id)] = accuracies[-1]

  print(clients_accuracies)
# Out:
# {'1': 0.0163443094629156, '5': 0.022158727621483375, '7': 0.013107416879795396, '16': 0.011588874680306905, '17': 0.012887627877237852, '18': 0.015764865728900256, '20': 0.025275735294117647, '22': 0.014046515345268542, '23': 0.01676390664961637, '25': 0.03123001918158568, '26': 0.024176790281329925, '27': 0.016264386189258313, '29': 0.02227861253196931, '30': 0.019301470588235295, '31': 0.0357456841432225, '37': 0.02042039641943734, '40': 0.034646739130434784, '43': 0.020899936061381075, '45': 0.02131953324808184, '46': 0.0154451726342711, '50': 0.010070332480818414, '52': 0.022878037084398978, '55': 0.026474584398976982, '56': 0.009750639386189258, '57': 0.029871323529411766, '60': 0.02485613810741688, '63': 0.028812340153452687, '70': 0.022238650895140665, '71': 0.03216911764705882, '72': 0.029171994884910485, '73': 0.023817135549872123, '74': 0.02563539002557545, '75': 0.015944693094629155, '76': 0.018242487212276216, '80': 0.028472666240409207, '81': 0.016284367007672634, '82': 0.021379475703324807, '84': 0.02203884271099744, '85': 0.010170236572890026, '86': 0.02387707800511509, '87': 0.03228900255754476, '88': 0.023857097186700767, '89': 0.014246323529411764, '92': 0.028292838874680308, '94': 0.027193893861892582, '95': 0.01996083759590793, '97': 0.025795236572890026, '99': 0.021619245524296674}

# %% [markdown]
# ## Create "fedmd_results" folder

# %%
if not os.path.isdir('fedmd_results'):
  PATH = os.getcwd() + '/fedmd_results'

  c_ids = [str(i) for i in range(100)]
  # !mkdir fedmd_results

  for c_id in c_ids:
    client_path = PATH + '/client' + c_id
    os.mkdir(client_path)

# %%
import torch
from torch.utils.data import Subset, DataLoader
from fedmd.server.server import Server
from fedmd.models_implementations.utils import save_model

NUM_ROUNDS = 50
SUBSET_BATCH_SIZE = 64 #128
NUM_SAMPLES_PER_ROUND = 39936 #5120 #the batch size was set to 128 and NUM_SAMPLES_PER_ROUND must be a multiple of the batch size

PATH = os.getcwd() + '/fedmd_results'

server = Server(clients, NUM_ROUNDS, public_train_dataloader, NUM_SAMPLES_PER_ROUND, SUBSET_BATCH_SIZE, ALPHA, "cuda")

starting_round = 0
if LOAD_CHECKPOINTS_FROM_PAST_ROUNDS is True:
  starting_round = last_round_performed + 1
  for c in clients_accuracies.keys():
    # update the dictionary of accuracies in the server with the latest accuracy of each client
    # some clients may have not participated in any rounds previously. They will have the accuracy obtained after "independent training". These accuracies are
    # loaded internally by the server

    # note: the purpose of this dictionary of accuracy is for computing the consensus using the weighted average, where clients with more accurate models
    # have higher weights
    server.accuracies[c] = clients_accuracies[c]

client_maxacc = {str(i): -1 for i in range(100)}

for round in range(starting_round, NUM_ROUNDS):
  print(f"############################################################## Begin round {round} ########################################################################")
  client_acc = server.perform_round()

  for c in client_acc.keys():
    # Save the best model
    if client_acc[c] > client_maxacc[c]:
      client_maxacc[c] = client_acc[c]
      path_best = PATH + "/client" + c + '/best_model_' + str(ALPHA) + '.pth'
      save_model(clients[int(c)]._model, path_best, round, client_maxacc[c])
    # Checkpoint
    path_checkpoint = PATH + "/client" + c + '/checkpoint_' + str(ALPHA) + '.pth'
    save_model(clients[int(c)]._model, path_checkpoint, round, client_acc[c])

    # Record stats
    stats_path = PATH + '/client' + c + '/stats_' + str(ALPHA) + '.csv'
    with open(stats_path, "a") as f:
      if round == 0:
        f.write("round,accuracy\n")
      f.write(f"{round},{client_acc[c]}\n")

  zip_name = f"/content/fedmd_results_round{round}.zip"
  destination_path = f"/content/drive/MyDrive/understanding_federated_learning_project/fedmd_collaboration_results_{ALPHA}"
  # !zip -r {zip_name} /content/fedmd_results/
  # !cp {zip_name} {destination_path}
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/fedmd_results/client45/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client45/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client36/ (stored 0%)
#   adding: content/fedmd_results/client36/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client36/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client36/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client43/ (stored 0%)
#   adding: content/fedmd_results/client43/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client43/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client43/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client22/ (stored 0%)
#   adding: content/fedmd_results/client22/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client22/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client22/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client15/ (stored 0%)
#   adding: content/fedmd_results/client15/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client15/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client15/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client98/ (stored 0%)
#   adding: content/fedmd_results/client98/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client98/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client98/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client67/ (stored 0%)
#   adding: content/fedmd_results/client67/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client67/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client67/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client58/ (stored 0%)
#   adding: content/fedmd_results/client58/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client58/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client58/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client7/ (stored 0%)
#   adding: content/fedmd_results/client7/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client7/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client7/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client83/ (stored 0%)
#   adding: content/fedmd_results/client83/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client83/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client83/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client59/ (stored 0%)
#   adding: content/fedmd_results/client8/ (stored 0%)
#   adding: content/fedmd_results/client31/ (stored 0%)
#   adding: content/fedmd_results/client31/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client31/stats_0.0.csv (deflated 32%)
#   adding: content/fedmd_results/client31/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client78/ (stored 0%)
#   adding: content/fedmd_results/client88/ (stored 0%)
#   adding: content/fedmd_results/client88/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client88/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client88/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/ (stored 0%)
#   adding: content/fedmd_results/client68/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client68/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/ (stored 0%)
#   adding: content/fedmd_results/client26/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client26/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client0/ (stored 0%)
#   adding: content/fedmd_results/client17/ (stored 0%)
#   adding: content/fedmd_results/client17/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client17/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client17/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client72/ (stored 0%)
#   adding: content/fedmd_results/client72/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client72/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client72/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client93/ (stored 0%)
#   adding: content/fedmd_results/client93/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client93/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client93/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client38/ (stored 0%)
#   adding: content/fedmd_results/client38/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client38/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client38/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client81/ (stored 0%)
#   adding: content/fedmd_results/client81/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client81/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client81/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client21/ (stored 0%)
#   adding: content/fedmd_results/client50/ (stored 0%)
#   adding: content/fedmd_results/client50/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client50/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client50/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client97/ (stored 0%)
#   adding: content/fedmd_results/client97/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client97/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client97/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client77/ (stored 0%)
#   adding: content/fedmd_results/client77/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client77/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client77/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client86/ (stored 0%)
#   adding: content/fedmd_results/client86/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client86/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client86/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client11/ (stored 0%)
#   adding: content/fedmd_results/client11/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client11/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client11/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/ (stored 0%)
#   adding: content/fedmd_results/client29/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client29/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client23/ (stored 0%)
#   adding: content/fedmd_results/client23/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client23/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client23/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client2/ (stored 0%)
#   adding: content/fedmd_results/client85/ (stored 0%)
#   adding: content/fedmd_results/client85/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client85/stats_0.0.csv (deflated 32%)
#   adding: content/fedmd_results/client85/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/ (stored 0%)
#   adding: content/fedmd_results/client70/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client70/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client44/ (stored 0%)
#   adding: content/fedmd_results/client12/ (stored 0%)
#   adding: content/fedmd_results/client12/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client12/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client12/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client19/ (stored 0%)
#   adding: content/fedmd_results/client95/ (stored 0%)
#   adding: content/fedmd_results/client95/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client95/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client95/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client40/ (stored 0%)
#   adding: content/fedmd_results/client40/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client40/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client40/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client90/ (stored 0%)
#   adding: content/fedmd_results/client57/ (stored 0%)
#   adding: content/fedmd_results/client57/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client57/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client57/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client32/ (stored 0%)
#   adding: content/fedmd_results/client32/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client32/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client32/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client34/ (stored 0%)
#   adding: content/fedmd_results/client34/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client34/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client34/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client28/ (stored 0%)
#   adding: content/fedmd_results/client28/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client28/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client28/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client14/ (stored 0%)
#   adding: content/fedmd_results/client4/ (stored 0%)
#   adding: content/fedmd_results/client91/ (stored 0%)
#   adding: content/fedmd_results/client63/ (stored 0%)
#   adding: content/fedmd_results/client63/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client63/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client63/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client16/ (stored 0%)
#   adding: content/fedmd_results/client16/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client16/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client16/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client1/ (stored 0%)
#   adding: content/fedmd_results/client1/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client1/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client1/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client53/ (stored 0%)
#   adding: content/fedmd_results/client53/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client53/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client53/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client3/ (stored 0%)
#   adding: content/fedmd_results/client3/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client3/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client3/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/ (stored 0%)
#   adding: content/fedmd_results/client51/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/stats_0.0.csv (deflated 27%)
#   adding: content/fedmd_results/client51/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client56/ (stored 0%)
#   adding: content/fedmd_results/client56/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client56/stats_0.0.csv (deflated 35%)
#   adding: content/fedmd_results/client56/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client52/ (stored 0%)
#   adding: content/fedmd_results/client52/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client52/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client52/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client82/ (stored 0%)
#   adding: content/fedmd_results/client82/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client82/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client82/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client60/ (stored 0%)
#   adding: content/fedmd_results/client60/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client60/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client60/checkpoint_0.0.pth (deflated 13%)
# ############################################################## Begin round 16 ########################################################################
# Clients begin computing the scores
#
# Client 2 starts computing scores.
#
# Client 15 starts computing scores.
#
# Client 16 starts computing scores.
#
# Client 23 starts computing scores.
#
# Client 24 starts computing scores.
#
# Client 30 starts computing scores.
#
# Client 52 starts computing scores.
#
# Client 70 starts computing scores.
#
# Client 75 starts computing scores.
#
# Client 87 starts computing scores.
#
# Server computes consensus
#
# Server distributes the consensus
#
# Clients start digesting the consensus and training on their private data for few epochs
#
# Client 2 starts digest phase
#
# Validation accuracy before digest: 0.009990409207161126
# Client 2 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.024136828644501278
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.02922215828528771
# Current Val Accuracy = 0.011508951406649617
# Max Validation Accuracy: 0
# Client 15 starts digest phase
#
# Validation accuracy before digest: 0.01740329283887468
# Client 15 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.027213874680306907
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.02939736843109131
# Current Val Accuracy = 0.025595428388746802
# Max Validation Accuracy: 0
# Client 16 starts digest phase
#
# Validation accuracy before digest: 0.022398497442455242
# Client 16 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.036804667519181586
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029337546764275968
# Current Val Accuracy = 0.013906649616368286
# Max Validation Accuracy: 0
# Client 23 starts digest phase
#
# Validation accuracy before digest: 0.018062659846547313
# Client 23 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03684462915601023
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029387633005777996
# Current Val Accuracy = 0.02591512148337596
# Max Validation Accuracy: 0
# Client 24 starts digest phase
#
# Validation accuracy before digest: 0.019061700767263427
# Client 24 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.0296315537084399
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029129722179510653
# Current Val Accuracy = 0.018781969309462916
# Max Validation Accuracy: 0
# Client 30 starts digest phase
#
# Validation accuracy before digest: 0.03009111253196931
# Client 30 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03808343989769821
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029403319725623496
# Current Val Accuracy = 0.035885549872122766
# Max Validation Accuracy: 0
# Client 52 starts digest phase
#
# Validation accuracy before digest: 0.022878037084398978
# Client 52 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03324808184143223
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029236762951581906
# Current Val Accuracy = 0.02283807544757033
# Max Validation Accuracy: 0
# Client 70 starts digest phase
#
# Validation accuracy before digest: 0.029751438618925832
# Client 70 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03592551150895141
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029285024373959273
# Current Val Accuracy = 0.017003676470588234
# Max Validation Accuracy: 0
# Client 75 starts digest phase
#
# Validation accuracy before digest: 0.028712436061381075
# Client 75 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03658487851662404
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029416325764778335
# Current Val Accuracy = 0.03436700767263427
# Max Validation Accuracy: 0
# Client 87 starts digest phase
#
# Validation accuracy before digest: 0.03228900255754476
# Client 87 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.039202365728900256
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.02947867527986184
# Current Val Accuracy = 0.03616528132992328
# Max Validation Accuracy: 0
# Perform validation on every client
#
# Client 2 accuracy: 0.011508951406649617
#
# Client 15 accuracy: 0.025595428388746802
#
# Client 16 accuracy: 0.013906649616368286
#
# Client 23 accuracy: 0.02591512148337596
#
# Client 24 accuracy: 0.018781969309462916
#
# Client 30 accuracy: 0.035885549872122766
#
# Client 52 accuracy: 0.02283807544757033
#
# Client 70 accuracy: 0.017003676470588234
#
# Client 75 accuracy: 0.03436700767263427
#
# Client 87 accuracy: 0.03616528132992328
#
# Selected clients: ['54', '90', '78', '63', '28', '84', '69', '71', '3', '30']
#
#   adding: content/fedmd_results/ (stored 0%)
#   adding: content/fedmd_results/client69/ (stored 0%)
#   adding: content/fedmd_results/client69/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client69/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client69/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client65/ (stored 0%)
#   adding: content/fedmd_results/client65/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client65/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client65/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client80/ (stored 0%)
#   adding: content/fedmd_results/client80/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client80/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client80/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client71/ (stored 0%)
#   adding: content/fedmd_results/client71/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client71/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client71/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client92/ (stored 0%)
#   adding: content/fedmd_results/client92/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client92/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client92/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client24/ (stored 0%)
#   adding: content/fedmd_results/client24/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client24/stats_0.0.csv (deflated 28%)
#   adding: content/fedmd_results/client24/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client87/ (stored 0%)
#   adding: content/fedmd_results/client87/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client87/stats_0.0.csv (deflated 31%)
#   adding: content/fedmd_results/client87/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client18/ (stored 0%)
#   adding: content/fedmd_results/client18/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client18/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client18/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client13/ (stored 0%)
#   adding: content/fedmd_results/client41/ (stored 0%)
#   adding: content/fedmd_results/client35/ (stored 0%)
#   adding: content/fedmd_results/client73/ (stored 0%)
#   adding: content/fedmd_results/client73/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client73/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client73/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client5/ (stored 0%)
#   adding: content/fedmd_results/client5/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client5/stats_0.0.csv (deflated 32%)
#   adding: content/fedmd_results/client5/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client94/ (stored 0%)
#   adding: content/fedmd_results/client94/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client94/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client94/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client74/ (stored 0%)
#   adding: content/fedmd_results/client74/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client74/stats_0.0.csv (deflated 22%)
#   adding: content/fedmd_results/client74/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client37/ (stored 0%)
#   adding: content/fedmd_results/client37/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client37/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client37/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client30/ (stored 0%)
#   adding: content/fedmd_results/client30/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client30/stats_0.0.csv (deflated 33%)
#   adding: content/fedmd_results/client30/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client89/ (stored 0%)
#   adding: content/fedmd_results/client89/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client89/stats_0.0.csv (deflated 25%)
#   adding: content/fedmd_results/client89/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client20/ (stored 0%)
#   adding: content/fedmd_results/client20/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client20/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client20/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client84/ (stored 0%)
#   adding: content/fedmd_results/client84/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client84/stats_0.0.csv (deflated 25%)
#   adding: content/fedmd_results/client84/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client66/ (stored 0%)
#   adding: content/fedmd_results/client9/ (stored 0%)
#   adding: content/fedmd_results/client9/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client9/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client9/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client55/ (stored 0%)
#   adding: content/fedmd_results/client55/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client55/stats_0.0.csv (deflated 18%)
#   adding: content/fedmd_results/client55/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client10/ (stored 0%)
#   adding: content/fedmd_results/client6/ (stored 0%)
#   adding: content/fedmd_results/client6/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client6/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client6/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client46/ (stored 0%)
#   adding: content/fedmd_results/client46/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client46/stats_0.0.csv (deflated 22%)
#   adding: content/fedmd_results/client46/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client49/ (stored 0%)
#   adding: content/fedmd_results/client49/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client49/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client49/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client64/ (stored 0%)
#   adding: content/fedmd_results/client64/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client64/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client64/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client25/ (stored 0%)
#   adding: content/fedmd_results/client25/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client25/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client25/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client47/ (stored 0%)
#   adding: content/fedmd_results/client47/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client47/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client47/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client62/ (stored 0%)
#   adding: content/fedmd_results/client62/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client62/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client62/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client33/ (stored 0%)
#   adding: content/fedmd_results/client33/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client33/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client33/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client39/ (stored 0%)
#   adding: content/fedmd_results/client39/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client39/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client39/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client79/ (stored 0%)
#   adding: content/fedmd_results/client99/ (stored 0%)
#   adding: content/fedmd_results/client99/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client99/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client99/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client61/ (stored 0%)
#   adding: content/fedmd_results/client61/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client61/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client61/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client48/ (stored 0%)
#   adding: content/fedmd_results/client48/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client48/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client48/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client27/ (stored 0%)
#   adding: content/fedmd_results/client27/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client27/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client27/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client42/ (stored 0%)
#   adding: content/fedmd_results/client75/ (stored 0%)
#   adding: content/fedmd_results/client75/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client75/stats_0.0.csv (deflated 33%)
#   adding: content/fedmd_results/client75/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client76/ (stored 0%)
#   adding: content/fedmd_results/client76/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client76/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client76/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client96/ (stored 0%)
#   adding: content/fedmd_results/client96/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client96/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client96/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client54/ (stored 0%)
#   adding: content/fedmd_results/client45/ (stored 0%)
#   adding: content/fedmd_results/client45/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client45/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client45/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client36/ (stored 0%)
#   adding: content/fedmd_results/client36/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client36/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client36/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client43/ (stored 0%)
#   adding: content/fedmd_results/client43/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client43/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client43/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client22/ (stored 0%)
#   adding: content/fedmd_results/client22/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client22/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client22/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client15/ (stored 0%)
#   adding: content/fedmd_results/client15/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client15/stats_0.0.csv (deflated 17%)
#   adding: content/fedmd_results/client15/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client98/ (stored 0%)
#   adding: content/fedmd_results/client98/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client98/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client98/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client67/ (stored 0%)
#   adding: content/fedmd_results/client67/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client67/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client67/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client58/ (stored 0%)
#   adding: content/fedmd_results/client58/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client58/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client58/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client7/ (stored 0%)
#   adding: content/fedmd_results/client7/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client7/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client7/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client83/ (stored 0%)
#   adding: content/fedmd_results/client83/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client83/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client83/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client59/ (stored 0%)
#   adding: content/fedmd_results/client8/ (stored 0%)
#   adding: content/fedmd_results/client31/ (stored 0%)
#   adding: content/fedmd_results/client31/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client31/stats_0.0.csv (deflated 32%)
#   adding: content/fedmd_results/client31/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client78/ (stored 0%)
#   adding: content/fedmd_results/client88/ (stored 0%)
#   adding: content/fedmd_results/client88/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client88/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client88/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/ (stored 0%)
#   adding: content/fedmd_results/client68/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client68/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/ (stored 0%)
#   adding: content/fedmd_results/client26/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client26/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client0/ (stored 0%)
#   adding: content/fedmd_results/client17/ (stored 0%)
#   adding: content/fedmd_results/client17/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client17/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client17/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client72/ (stored 0%)
#   adding: content/fedmd_results/client72/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client72/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client72/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client93/ (stored 0%)
#   adding: content/fedmd_results/client93/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client93/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client93/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client38/ (stored 0%)
#   adding: content/fedmd_results/client38/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client38/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client38/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client81/ (stored 0%)
#   adding: content/fedmd_results/client81/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client81/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client81/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client21/ (stored 0%)
#   adding: content/fedmd_results/client50/ (stored 0%)
#   adding: content/fedmd_results/client50/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client50/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client50/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client97/ (stored 0%)
#   adding: content/fedmd_results/client97/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client97/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client97/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client77/ (stored 0%)
#   adding: content/fedmd_results/client77/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client77/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client77/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client86/ (stored 0%)
#   adding: content/fedmd_results/client86/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client86/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client86/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client11/ (stored 0%)
#   adding: content/fedmd_results/client11/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client11/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client11/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/ (stored 0%)
#   adding: content/fedmd_results/client29/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client29/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client23/ (stored 0%)
#   adding: content/fedmd_results/client23/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client23/stats_0.0.csv (deflated 25%)
#   adding: content/fedmd_results/client23/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client2/ (stored 0%)
#   adding: content/fedmd_results/client2/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client2/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client2/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client85/ (stored 0%)
#   adding: content/fedmd_results/client85/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client85/stats_0.0.csv (deflated 32%)
#   adding: content/fedmd_results/client85/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/ (stored 0%)
#   adding: content/fedmd_results/client70/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client70/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client44/ (stored 0%)
#   adding: content/fedmd_results/client12/ (stored 0%)
#   adding: content/fedmd_results/client12/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client12/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client12/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client19/ (stored 0%)
#   adding: content/fedmd_results/client95/ (stored 0%)
#   adding: content/fedmd_results/client95/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client95/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client95/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client40/ (stored 0%)
#   adding: content/fedmd_results/client40/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client40/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client40/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client90/ (stored 0%)
#   adding: content/fedmd_results/client57/ (stored 0%)
#   adding: content/fedmd_results/client57/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client57/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client57/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client32/ (stored 0%)
#   adding: content/fedmd_results/client32/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client32/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client32/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client34/ (stored 0%)
#   adding: content/fedmd_results/client34/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client34/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client34/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client28/ (stored 0%)
#   adding: content/fedmd_results/client28/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client28/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client28/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client14/ (stored 0%)
#   adding: content/fedmd_results/client4/ (stored 0%)
#   adding: content/fedmd_results/client91/ (stored 0%)
#   adding: content/fedmd_results/client63/ (stored 0%)
#   adding: content/fedmd_results/client63/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client63/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client63/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client16/ (stored 0%)
#   adding: content/fedmd_results/client16/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client16/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client16/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client1/ (stored 0%)
#   adding: content/fedmd_results/client1/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client1/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client1/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client53/ (stored 0%)
#   adding: content/fedmd_results/client53/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client53/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client53/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client3/ (stored 0%)
#   adding: content/fedmd_results/client3/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client3/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client3/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/ (stored 0%)
#   adding: content/fedmd_results/client51/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/stats_0.0.csv (deflated 27%)
#   adding: content/fedmd_results/client51/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client56/ (stored 0%)
#   adding: content/fedmd_results/client56/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client56/stats_0.0.csv (deflated 35%)
#   adding: content/fedmd_results/client56/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client52/ (stored 0%)
#   adding: content/fedmd_results/client52/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client52/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client52/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client82/ (stored 0%)
#   adding: content/fedmd_results/client82/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client82/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client82/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client60/ (stored 0%)
#   adding: content/fedmd_results/client60/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client60/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client60/checkpoint_0.0.pth (deflated 13%)
# ############################################################## Begin round 17 ########################################################################
# Clients begin computing the scores
#
# Client 3 starts computing scores.
#
# Client 28 starts computing scores.
#
# Client 30 starts computing scores.
#
# Client 54 starts computing scores.
#
# Client 63 starts computing scores.
#
# Client 69 starts computing scores.
#
# Client 71 starts computing scores.
#
# Client 78 starts computing scores.
#
# Client 84 starts computing scores.
#
# Client 90 starts computing scores.
#
# Server computes consensus
#
# Server distributes the consensus
#
# Clients start digesting the consensus and training on their private data for few epochs
#
# Client 3 starts digest phase
#
# Validation accuracy before digest: 0.016204443734015344
# Client 3 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.020740089514066497
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.0293579896291097
# Current Val Accuracy = 0.012627877237851663
# Max Validation Accuracy: 0
# Client 28 starts digest phase
#
# Validation accuracy before digest: 0.012647858056265985
# Client 28 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.022937979539641943
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029346621953524075
# Current Val Accuracy = 0.01856218030690537
# Max Validation Accuracy: 0
# Client 30 starts digest phase
#
# Validation accuracy before digest: 0.035885549872122766
# Client 30 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.034746643222506396
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029451773716853216
# Current Val Accuracy = 0.03296835038363171
# Max Validation Accuracy: 0
# Client 54 starts digest phase
#
# Validation accuracy before digest: 0.009990409207161126
# Client 54 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.017982736572890026
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.030120290242708646
# Current Val Accuracy = 0.01622442455242967
# Max Validation Accuracy: 0
# Client 63 starts digest phase
#
# Validation accuracy before digest: 0.026334718670076727
# Client 63 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.038403132992327366
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029193639755249023
# Current Val Accuracy = 0.03916240409207161
# Max Validation Accuracy: 0
# Client 69 starts digest phase
#
# Validation accuracy before digest: 0.01294757033248082
# Client 69 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.017163523017902815
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.02940956140175844
# Current Val Accuracy = 0.01090952685421995
# Max Validation Accuracy: 0
# Client 71 starts digest phase
#
# Validation accuracy before digest: 0.03216911764705882
# Client 71 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.034586796675191815
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029349868114177998
# Current Val Accuracy = 0.03186940537084399
# Max Validation Accuracy: 0
# Client 78 starts digest phase
#
# Validation accuracy before digest: 0.009990409207161126
# Client 78 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.016983695652173912
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029447020628513433
# Current Val Accuracy = 0.010350063938618925
# Max Validation Accuracy: 0
# Client 84 starts digest phase
#
# Validation accuracy before digest: 0.02697410485933504
# Client 84 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.03494645140664961
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029491555996430226
# Current Val Accuracy = 0.03308823529411765
# Max Validation Accuracy: 0
# Client 90 starts digest phase
#
# Validation accuracy before digest: 0.009990409207161126
# Client 90 revisits its private data for 1 epochs
#
# Current Val Accuracy right after digest and before revisit = 0.012807704603580562
#
# Starting epoch 1/1, LR = 0.001
# Current Avg Loss = 0.029025013630206768
# Current Val Accuracy = 0.011528932225063938
# Max Validation Accuracy: 0
# Perform validation on every client
#
# Client 3 accuracy: 0.012627877237851663
#
# Client 28 accuracy: 0.01856218030690537
#
# Client 30 accuracy: 0.03296835038363171
#
# Client 54 accuracy: 0.01622442455242967
#
# Client 63 accuracy: 0.03916240409207161
#
# Client 69 accuracy: 0.01090952685421995
#
# Client 71 accuracy: 0.03186940537084399
#
# Client 78 accuracy: 0.010350063938618925
#
# Client 84 accuracy: 0.03308823529411765
#
# Client 90 accuracy: 0.011528932225063938
#
# Selected clients: ['11', '90', '45', '92', '99', '8', '5', '0', '21', '76']
#
#   adding: content/fedmd_results/ (stored 0%)
#   adding: content/fedmd_results/client69/ (stored 0%)
#   adding: content/fedmd_results/client69/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client69/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client69/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client65/ (stored 0%)
#   adding: content/fedmd_results/client65/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client65/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client65/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client80/ (stored 0%)
#   adding: content/fedmd_results/client80/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client80/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client80/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client71/ (stored 0%)
#   adding: content/fedmd_results/client71/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client71/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client71/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client92/ (stored 0%)
#   adding: content/fedmd_results/client92/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client92/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client92/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client24/ (stored 0%)
#   adding: content/fedmd_results/client24/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client24/stats_0.0.csv (deflated 28%)
#   adding: content/fedmd_results/client24/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client87/ (stored 0%)
#   adding: content/fedmd_results/client87/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client87/stats_0.0.csv (deflated 31%)
#   adding: content/fedmd_results/client87/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client18/ (stored 0%)
#   adding: content/fedmd_results/client18/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client18/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client18/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client13/ (stored 0%)
#   adding: content/fedmd_results/client41/ (stored 0%)
#   adding: content/fedmd_results/client35/ (stored 0%)
#   adding: content/fedmd_results/client73/ (stored 0%)
#   adding: content/fedmd_results/client73/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client73/stats_0.0.csv (stored 0%)
# ...
#   adding: content/fedmd_results/client78/stats_0.0.csv (deflated 10%)
#   adding: content/fedmd_results/client78/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client88/ (stored 0%)
#   adding: content/fedmd_results/client88/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client88/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client88/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/ (stored 0%)
#   adding: content/fedmd_results/client68/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client68/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client68/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/ (stored 0%)
#   adding: content/fedmd_results/client26/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client26/stats_0.0.csv (deflated 3%)
#   adding: content/fedmd_results/client26/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client0/ (stored 0%)
#   adding: content/fedmd_results/client0/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client0/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client0/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client17/ (stored 0%)
#   adding: content/fedmd_results/client17/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client17/stats_0.0.csv (deflated 31%)
#   adding: content/fedmd_results/client17/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client72/ (stored 0%)
#   adding: content/fedmd_results/client72/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client72/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client72/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client93/ (stored 0%)
#   adding: content/fedmd_results/client93/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client93/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client93/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client38/ (stored 0%)
#   adding: content/fedmd_results/client38/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client38/stats_0.0.csv (deflated 26%)
#   adding: content/fedmd_results/client38/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client81/ (stored 0%)
#   adding: content/fedmd_results/client81/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client81/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client81/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client21/ (stored 0%)
#   adding: content/fedmd_results/client21/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client21/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client21/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client50/ (stored 0%)
#   adding: content/fedmd_results/client50/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client50/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client50/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client97/ (stored 0%)
#   adding: content/fedmd_results/client97/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client97/stats_0.0.csv (deflated 5%)
#   adding: content/fedmd_results/client97/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client77/ (stored 0%)
#   adding: content/fedmd_results/client77/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client77/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client77/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client86/ (stored 0%)
#   adding: content/fedmd_results/client86/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client86/stats_0.0.csv (deflated 25%)
#   adding: content/fedmd_results/client86/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client11/ (stored 0%)
#   adding: content/fedmd_results/client11/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client11/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client11/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/ (stored 0%)
#   adding: content/fedmd_results/client29/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client29/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client29/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client23/ (stored 0%)
#   adding: content/fedmd_results/client23/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client23/stats_0.0.csv (deflated 33%)
#   adding: content/fedmd_results/client23/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client2/ (stored 0%)
#   adding: content/fedmd_results/client2/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client2/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client2/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client85/ (stored 0%)
#   adding: content/fedmd_results/client85/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client85/stats_0.0.csv (deflated 37%)
#   adding: content/fedmd_results/client85/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/ (stored 0%)
#   adding: content/fedmd_results/client70/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client70/stats_0.0.csv (deflated 15%)
#   adding: content/fedmd_results/client70/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client44/ (stored 0%)
#   adding: content/fedmd_results/client12/ (stored 0%)
#   adding: content/fedmd_results/client12/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client12/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client12/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client19/ (stored 0%)
#   adding: content/fedmd_results/client19/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client19/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client19/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client95/ (stored 0%)
#   adding: content/fedmd_results/client95/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client95/stats_0.0.csv (deflated 33%)
#   adding: content/fedmd_results/client95/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client40/ (stored 0%)
#   adding: content/fedmd_results/client40/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client40/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client40/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client90/ (stored 0%)
#   adding: content/fedmd_results/client90/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client90/stats_0.0.csv (deflated 10%)
#   adding: content/fedmd_results/client90/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client57/ (stored 0%)
#   adding: content/fedmd_results/client57/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client57/stats_0.0.csv (deflated 23%)
#   adding: content/fedmd_results/client57/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client32/ (stored 0%)
#   adding: content/fedmd_results/client32/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client32/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client32/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client34/ (stored 0%)
#   adding: content/fedmd_results/client34/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client34/stats_0.0.csv (deflated 9%)
#   adding: content/fedmd_results/client34/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client28/ (stored 0%)
#   adding: content/fedmd_results/client28/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client28/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client28/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client14/ (stored 0%)
#   adding: content/fedmd_results/client4/ (stored 0%)
#   adding: content/fedmd_results/client4/best_model_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client4/stats_0.0.csv (stored 0%)
#   adding: content/fedmd_results/client4/checkpoint_0.0.pth (deflated 10%)
#   adding: content/fedmd_results/client91/ (stored 0%)
#   adding: content/fedmd_results/client91/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client91/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client91/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client63/ (stored 0%)
#   adding: content/fedmd_results/client63/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client63/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client63/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client16/ (stored 0%)
#   adding: content/fedmd_results/client16/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client16/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client16/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client1/ (stored 0%)
#   adding: content/fedmd_results/client1/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client1/stats_0.0.csv (deflated 7%)
#   adding: content/fedmd_results/client1/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client53/ (stored 0%)
#   adding: content/fedmd_results/client53/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client53/stats_0.0.csv (deflated 10%)
#   adding: content/fedmd_results/client53/checkpoint_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client3/ (stored 0%)
#   adding: content/fedmd_results/client3/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client3/stats_0.0.csv (deflated 13%)
#   adding: content/fedmd_results/client3/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/ (stored 0%)
#   adding: content/fedmd_results/client51/best_model_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client51/stats_0.0.csv (deflated 27%)
#   adding: content/fedmd_results/client51/checkpoint_0.0.pth (deflated 9%)
#   adding: content/fedmd_results/client56/ (stored 0%)
#   adding: content/fedmd_results/client56/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client56/stats_0.0.csv (deflated 35%)
#   adding: content/fedmd_results/client56/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client52/ (stored 0%)
#   adding: content/fedmd_results/client52/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client52/stats_0.0.csv (deflated 24%)
#   adding: content/fedmd_results/client52/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client82/ (stored 0%)
#   adding: content/fedmd_results/client82/best_model_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client82/stats_0.0.csv (deflated 11%)
#   adding: content/fedmd_results/client82/checkpoint_0.0.pth (deflated 8%)
#   adding: content/fedmd_results/client60/ (stored 0%)
#   adding: content/fedmd_results/client60/best_model_0.0.pth (deflated 13%)
#   adding: content/fedmd_results/client60/stats_0.0.csv (deflated 33%)
#   adding: content/fedmd_results/client60/checkpoint_0.0.pth (deflated 13%)
# ############################################################## Begin round 25 ########################################################################
# Clients begin computing the scores
#
# Client 19 starts computing scores.
#
# Client 33 starts computing scores.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2d833541e1ba> in <cell line: 28>()
#      28 for round in range(starting_round, NUM_ROUNDS):
#      29   print(f"############################################################## Begin round {round} ########################################################################")
# ---> 30   client_acc = server.perform_round()
#      31
#      32   for c in client_acc.keys():
#
# /content/fedmd/server/server.py in perform_round(self)
#      74
#      75         print("Clients begin computing the scores\n")
# ---> 76         self.receive()
#      77         print("Server computes consensus\n")
#      78         self.update()
#
# /content/fedmd/server/server.py in receive(self)
#     139
#     140     def receive(self):
# --> 141         self.clients_scores = {client.client_id: client.upload() for client in self.selected_clients}
#     142
#     143     def update(self):
#
# /content/fedmd/server/server.py in <dictcomp>(.0)
#     139
#     140     def receive(self):
# --> 141         self.clients_scores = {client.client_id: client.upload() for client in self.selected_clients}
#     142
#     143     def update(self):
#
# /content/fedmd/client/client.py in upload(self)
#      60             #self.current_local_scores.append(self._model(x))
#      61
# ---> 62             self.current_local_scores[i] = self._model(x).detach() #softmax applied on server side when computing consensus .softmax(dim=1, dtype=float).detach()
#      63             i += 1
#      64
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/fedmd/models_implementations/shufflenetv2.py in forward(self, x)
#     121
#     122     def forward(self, x):
# --> 123         return self._forward_impl(x)
#
# /content/fedmd/models_implementations/shufflenetv2.py in _forward_impl(self, x)
#     112         x = self.conv1(x)
#     113         #x = self.maxpool(x)
# --> 114         x = self.stage2(x)
#     115         x = self.stage3(x)
#     116         x = self.stage4(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/fedmd/models_implementations/shufflenetv2.py in forward(self, x)
#      60         if self.stride == 1:
#      61             x1, x2 = x.chunk(2, dim=1)
# ---> 62             out = torch.cat((x1, self.branch2(x2)), dim=1)
#      63         else:
#      64             out = torch.cat((self.branch1(x), self.branch2(x)), dim=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1602         if '_parameters' in self.__dict__:
#    1603             _parameters = self.__dict__['_parameters']
# -> 1604             if name in _parameters:
#    1605                 return _parameters[name]
#    1606         if '_buffers' in self.__dict__:
#
# KeyboardInterrupt:
