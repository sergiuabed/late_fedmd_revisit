# %% [markdown]
# # Setup

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Install required libraries

# %%
# !pip3 install 'torch'
# !pip3 install 'torchvision'
# !pip3 install 'pillow'
# !pip3 install 'tqdm'
# !pip3 install 'matplotlib'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.0+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (16.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0->torchvision) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Clone GitHub repository

# %%
import os

if not os.path.isdir('fedmd'):
  # !git clone https://github.com/sergiuabed/fedmd
  # %cd fedmd/
  # !git checkout experiment
  # %cd ..
else:
  # %cd fedmd/
  # !git pull origin
  # %cd ..

if not os.path.isdir('fedmd/baseline_public_cifar10'):
  # !mkdir fedmd/baseline_public_cifar10
# Out:
# Cloning into 'fedmd'...
# remote: Enumerating objects: 2157, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 2157 (delta 17), reused 24 (delta 12), pack-reused 2125
# Receiving objects: 100% (2157/2157), 314.62 MiB | 25.76 MiB/s, done.
# Resolving deltas: 100% (781/781), done.
# /content/fedmd
# Updating files: 100% (416/416), done.
# Branch 'experiment' set up to track remote branch 'experiment' from 'origin'.
# Switched to a new branch 'experiment'
# /content

# %% [markdown]
# ## Import libraries

# %%
from fedmd.models_implementations.resnet import ResNet
from fedmd.models_implementations.densenet import DenseNet
from fedmd.models_implementations.shufflenetv2 import ShuffleNetV2
from fedmd.models_implementations.utils import model_size, plot_stats
from fedmd.models_implementations.train_on_cifar import train_on_cifar
from fedmd.data_utils import read_data_splits
from fedmd.client.private_dataloader import ClientPrivateDataset
from torch.utils.data import DataLoader
from fedmd.client.client import Client

# %% [markdown]
# ## Define a function to read from file the training statistics

# %%
def read_stats(file_path:str) -> tuple[list]:
    with open(file_path, "r") as f:
        f.readline()
        lines = f.readlines()
    values = [line.rstrip("\n").split(",") for line in lines ]
    stats_tuples = [(int(v[0]), float(v[1]), float(v[2])) for v in values ]
    epochs, loss, acc = [list(i) for i in zip(*stats_tuples)]
    return epochs, loss, acc

# %% [markdown]
# #Train ResNet20
# In this notebook we train ResNet, DenseNet and ShuffleNet architectures in a centralized way, in order to obtain baselines for subsequent experiments.

# %% [markdown]
# ## Train ResNet20 on Cifar10

# %%
if not os.path.isdir('fedmd/baseline_public_cifar10/resnet20'):
  # !mkdir fedmd/baseline_public_cifar10/resnet20

  LR = 1e-1     
  MOMENTUM = 0.9       
  WEIGHT_DECAY = 1e-4  
  NUM_EPOCHS = 160
  FILE_PATH =  os.getcwd() + '/fedmd/baseline_public_cifar10/resnet20'
  NUM_CLASSES = 10
  GROUPS = 2
  LAYERS = [3, 3, 3]

  #!mkdir fedmd/baseline_public_cifar10/resnet20/resnet20_bn/
  #net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES)
  #print(f"Num Parameters = {model_size(net)}")
  #train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/resnet20_bn')


  # !mkdir fedmd/baseline_public_cifar10/resnet20/resnet20_gn/
  net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES, norm_layer="gn", groups=GROUPS)
  print(f"Num Parameters = {model_size(net)}")
  train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/resnet20_gn')
# Out:
# Num Parameters = 2372
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 29942715.70it/s]
# Extracting /content/cifar-10-python.tar.gz to /content
# Files already downloaded and verified
# Train Dataset: 40000
# Valid Dataset: 10000
# Test Dataset: 10000
# Starting epoch 1/160, LR = 0.1
# Current Avg Loss = 2.356976631360176
# Current Val Accuracy = 0.24091796875
# Starting epoch 2/160, LR = 0.1
# Current Avg Loss = 1.9335980537610176
# Current Val Accuracy = 0.33544921875
# Starting epoch 3/160, LR = 0.1
# Current Avg Loss = 1.8062691321739783
# Current Val Accuracy = 0.38984375
# Starting epoch 4/160, LR = 0.1
# Current Avg Loss = 1.7329749082907653
# Current Val Accuracy = 0.39140625
# Starting epoch 5/160, LR = 0.1
# Current Avg Loss = 1.6701652331229968
# Current Val Accuracy = 0.44755859375
# Starting epoch 6/160, LR = 0.1
# Current Avg Loss = 1.6114219274276342
# Current Val Accuracy = 0.455859375
# Starting epoch 7/160, LR = 0.1
# Current Avg Loss = 1.5786737295297475
# Current Val Accuracy = 0.46943359375
# Starting epoch 8/160, LR = 0.1
# Current Avg Loss = 1.52775632418119
# Current Val Accuracy = 0.48291015625
# Starting epoch 9/160, LR = 0.1
# Current Avg Loss = 1.478196070744441
# Current Val Accuracy = 0.50576171875
# Starting epoch 10/160, LR = 0.1
# Current Avg Loss = 1.4430677951910558
# Current Val Accuracy = 0.45615234375
# Starting epoch 11/160, LR = 0.1
# Current Avg Loss = 1.4071756020570412
# Current Val Accuracy = 0.5392578125
# Starting epoch 12/160, LR = 0.1
# Current Avg Loss = 1.3726065219976964
# Current Val Accuracy = 0.571484375
# Starting epoch 13/160, LR = 0.1
# Current Avg Loss = 1.3406563783303285
# Current Val Accuracy = 0.5525390625
# Starting epoch 14/160, LR = 0.1
# Current Avg Loss = 1.2960946498773036
# Current Val Accuracy = 0.58857421875
# Starting epoch 15/160, LR = 0.1
# Current Avg Loss = 1.2814796643379407
# Current Val Accuracy = 0.583984375
# Starting epoch 16/160, LR = 0.1
# Current Avg Loss = 1.24919920701247
# Current Val Accuracy = 0.581640625
# Starting epoch 17/160, LR = 0.1
# Current Avg Loss = 1.222914769099309
# Current Val Accuracy = 0.60244140625
# Starting epoch 18/160, LR = 0.1
# Current Avg Loss = 1.1984417255108173
# Current Val Accuracy = 0.62275390625
# Starting epoch 19/160, LR = 0.1
# Current Avg Loss = 1.1760967939327924
# Current Val Accuracy = 0.6099609375
# Starting epoch 20/160, LR = 0.1
# Current Avg Loss = 1.1586227416992188
# Current Val Accuracy = 0.62119140625
# Starting epoch 21/160, LR = 0.1
# Current Avg Loss = 1.1335645822378306
# Current Val Accuracy = 0.60087890625
# Starting epoch 22/160, LR = 0.1
# Current Avg Loss = 1.128642840263171
# Current Val Accuracy = 0.6431640625
# Starting epoch 23/160, LR = 0.1
# Current Avg Loss = 1.0984905927609174
# Current Val Accuracy = 0.65322265625
# Starting epoch 24/160, LR = 0.1
# Current Avg Loss = 1.077291537553836
# Current Val Accuracy = 0.65830078125
# Starting epoch 25/160, LR = 0.1
# Current Avg Loss = 1.0537697229629908
# Current Val Accuracy = 0.64404296875
# Starting epoch 26/160, LR = 0.1
# Current Avg Loss = 1.0455633310171275
# Current Val Accuracy = 0.60908203125
# Starting epoch 27/160, LR = 0.1
# Current Avg Loss = 1.0364204797989283
# Current Val Accuracy = 0.6369140625
# Starting epoch 28/160, LR = 0.1
# Current Avg Loss = 1.02388430864383
# Current Val Accuracy = 0.6798828125
# Starting epoch 29/160, LR = 0.1
# Current Avg Loss = 1.003837683261969
# Current Val Accuracy = 0.62900390625
# Starting epoch 30/160, LR = 0.1
# Current Avg Loss = 0.9830915010892428
# Current Val Accuracy = 0.67392578125
# Starting epoch 31/160, LR = 0.1
# Current Avg Loss = 0.97344970703125
# Current Val Accuracy = 0.68388671875
# Starting epoch 32/160, LR = 0.1
# Current Avg Loss = 0.9578565939878806
# Current Val Accuracy = 0.6728515625
# Starting epoch 33/160, LR = 0.1
# Current Avg Loss = 0.9488319005721655
# Current Val Accuracy = 0.67978515625
# Starting epoch 34/160, LR = 0.1
# Current Avg Loss = 0.9390668624486679
# Current Val Accuracy = 0.6724609375
# Starting epoch 35/160, LR = 0.1
# Current Avg Loss = 0.9249298878205128
# Current Val Accuracy = 0.68525390625
# Starting epoch 36/160, LR = 0.1
# Current Avg Loss = 0.9218650230994592
# Current Val Accuracy = 0.70166015625
# Starting epoch 37/160, LR = 0.1
# Current Avg Loss = 0.9063916328625802
# Current Val Accuracy = 0.6984375
# Starting epoch 38/160, LR = 0.1
# Current Avg Loss = 0.9095319112141927
# Current Val Accuracy = 0.69716796875
# Starting epoch 39/160, LR = 0.1
# Current Avg Loss = 0.8955642504569812
# Current Val Accuracy = 0.70869140625
# Starting epoch 40/160, LR = 0.1
# Current Avg Loss = 0.8823551275791266
# Current Val Accuracy = 0.680078125
# Starting epoch 41/160, LR = 0.1
# Current Avg Loss = 0.8717484107384315
# Current Val Accuracy = 0.6888671875
# Starting epoch 42/160, LR = 0.1
# Current Avg Loss = 0.8742555471567007
# Current Val Accuracy = 0.72451171875
# Starting epoch 43/160, LR = 0.1
# Current Avg Loss = 0.8559136023888221
# Current Val Accuracy = 0.69365234375
# Starting epoch 44/160, LR = 0.1
# Current Avg Loss = 0.8661448160807291
# Current Val Accuracy = 0.71708984375
# Starting epoch 45/160, LR = 0.1
# Current Avg Loss = 0.8480763557629708
# Current Val Accuracy = 0.70927734375
# Starting epoch 46/160, LR = 0.1
# Current Avg Loss = 0.84113282423753
# Current Val Accuracy = 0.710546875
# Starting epoch 47/160, LR = 0.1
# Current Avg Loss = 0.8375582572741386
# Current Val Accuracy = 0.67099609375
# Starting epoch 48/160, LR = 0.1
# Current Avg Loss = 0.8366860609788161
# Current Val Accuracy = 0.69638671875
# Starting epoch 49/160, LR = 0.1
# Current Avg Loss = 0.8189369592911158
# Current Val Accuracy = 0.7224609375
# Starting epoch 50/160, LR = 0.1
# Current Avg Loss = 0.8110274290427183
# Current Val Accuracy = 0.7087890625
# Starting epoch 51/160, LR = 0.1
# Current Avg Loss = 0.8080979860745944
# Current Val Accuracy = 0.6990234375
# Starting epoch 52/160, LR = 0.1
# Current Avg Loss = 0.7967399694980719
# Current Val Accuracy = 0.74267578125
# Starting epoch 53/160, LR = 0.1
# Current Avg Loss = 0.8010340470534104
# Current Val Accuracy = 0.7201171875
# Starting epoch 54/160, LR = 0.1
# Current Avg Loss = 0.7984291956974909
# Current Val Accuracy = 0.7080078125
# Starting epoch 55/160, LR = 0.1
# Current Avg Loss = 0.7885245787791717
# Current Val Accuracy = 0.7298828125
# Starting epoch 56/160, LR = 0.1
# Current Avg Loss = 0.7888147403032352
# Current Val Accuracy = 0.74755859375
# Starting epoch 57/160, LR = 0.1
# Current Avg Loss = 0.7855661343305539
# Current Val Accuracy = 0.73330078125
# Starting epoch 58/160, LR = 0.1
# Current Avg Loss = 0.7715587615966797
# Current Val Accuracy = 0.74609375
# Starting epoch 59/160, LR = 0.1
# Current Avg Loss = 0.7736194806221204
# Current Val Accuracy = 0.74521484375
# Starting epoch 60/160, LR = 0.1
# Current Avg Loss = 0.7712300618489584
# Current Val Accuracy = 0.73037109375
# Starting epoch 61/160, LR = 0.1
# Current Avg Loss = 0.7656934200189053
# Current Val Accuracy = 0.74697265625
# Starting epoch 62/160, LR = 0.1
# Current Avg Loss = 0.7599843343098959
# Current Val Accuracy = 0.75283203125
# Starting epoch 63/160, LR = 0.1
# Current Avg Loss = 0.7537432939578326
# Current Val Accuracy = 0.72822265625
# Starting epoch 64/160, LR = 0.1
# Current Avg Loss = 0.7528638106126052
# Current Val Accuracy = 0.7599609375
# Starting epoch 65/160, LR = 0.1
# Current Avg Loss = 0.7486169766157101
# Current Val Accuracy = 0.75546875
# Starting epoch 66/160, LR = 0.1
# Current Avg Loss = 0.7429903470552884
# Current Val Accuracy = 0.7466796875
# Starting epoch 67/160, LR = 0.1
# Current Avg Loss = 0.7349418248885717
# Current Val Accuracy = 0.75244140625
# Starting epoch 68/160, LR = 0.1
# Current Avg Loss = 0.7377543327135917
# Current Val Accuracy = 0.73486328125
# Starting epoch 69/160, LR = 0.1
# Current Avg Loss = 0.7327562967936198
# Current Val Accuracy = 0.76767578125
# Starting epoch 70/160, LR = 0.1
# Current Avg Loss = 0.7423867445725661
# Current Val Accuracy = 0.73720703125
# Starting epoch 71/160, LR = 0.1
# Current Avg Loss = 0.7261562347412109
# Current Val Accuracy = 0.75341796875
# Starting epoch 72/160, LR = 0.1
# Current Avg Loss = 0.7165223635160006
# Current Val Accuracy = 0.74326171875
# Starting epoch 73/160, LR = 0.1
# Current Avg Loss = 0.7178492423815604
# Current Val Accuracy = 0.75146484375
# Starting epoch 74/160, LR = 0.1
# Current Avg Loss = 0.7128961025140225
# Current Val Accuracy = 0.768359375
# Starting epoch 75/160, LR = 0.1
# Current Avg Loss = 0.7100828610933744
# Current Val Accuracy = 0.75166015625
# Starting epoch 76/160, LR = 0.1
# Current Avg Loss = 0.7051560328556941
# Current Val Accuracy = 0.7564453125
# Starting epoch 77/160, LR = 0.1
# Current Avg Loss = 0.6957088861709986
# Current Val Accuracy = 0.77861328125
# Starting epoch 78/160, LR = 0.1
# Current Avg Loss = 0.7033639076428536
# Current Val Accuracy = 0.764453125
# Starting epoch 79/160, LR = 0.1
# Current Avg Loss = 0.701151138696915
# Current Val Accuracy = 0.7681640625
# Starting epoch 80/160, LR = 0.1
# Current Avg Loss = 0.6968106489915115
# Current Val Accuracy = 0.7775390625
# Starting epoch 81/160, LR = 0.1
# Current Avg Loss = 0.6978754385923728
# Current Val Accuracy = 0.760546875
# Starting epoch 82/160, LR = 0.1
# Current Avg Loss = 0.6907753577599158
# Current Val Accuracy = 0.76005859375
# Starting epoch 83/160, LR = 0.1
# Current Avg Loss = 0.6938494168795072
# Current Val Accuracy = 0.7681640625
# Starting epoch 84/160, LR = 0.1
# Current Avg Loss = 0.6895617460593199
# Current Val Accuracy = 0.77255859375
# Starting epoch 85/160, LR = 0.1
# Current Avg Loss = 0.6852976970183544
# Current Val Accuracy = 0.76845703125
# Starting epoch 86/160, LR = 0.1
# Current Avg Loss = 0.6817806928585737
# Current Val Accuracy = 0.7791015625
# Starting epoch 87/160, LR = 0.1
# Current Avg Loss = 0.685391597258739
# Current Val Accuracy = 0.78076171875
# Starting epoch 88/160, LR = 0.1
# Current Avg Loss = 0.6735226557804987
# Current Val Accuracy = 0.76044921875
# Starting epoch 89/160, LR = 0.1
# Current Avg Loss = 0.6695674504989233
# Current Val Accuracy = 0.74482421875
# Starting epoch 90/160, LR = 0.1
# Current Avg Loss = 0.6728820311717498
# Current Val Accuracy = 0.75830078125
# Starting epoch 91/160, LR = 0.1
# Current Avg Loss = 0.6717474521734775
# Current Val Accuracy = 0.77470703125
# Starting epoch 92/160, LR = 0.1
# Current Avg Loss = 0.6568065056434045
# Current Val Accuracy = 0.76162109375
# Starting epoch 93/160, LR = 0.1
# Current Avg Loss = 0.6636240543463291
# Current Val Accuracy = 0.7853515625
# Starting epoch 94/160, LR = 0.1
# Current Avg Loss = 0.6645533243815104
# Current Val Accuracy = 0.78505859375
# Starting epoch 95/160, LR = 0.1
# Current Avg Loss = 0.6562328338623047
# Current Val Accuracy = 0.755078125
# Starting epoch 96/160, LR = 0.1
# Current Avg Loss = 0.6483575380765475
# Current Val Accuracy = 0.778515625
# Starting epoch 97/160, LR = 0.1
# Current Avg Loss = 0.6488308539757361
# Current Val Accuracy = 0.78212890625
# Starting epoch 98/160, LR = 0.1
# Current Avg Loss = 0.656250733595628
# Current Val Accuracy = 0.78681640625
# Starting epoch 99/160, LR = 0.1
# Current Avg Loss = 0.6487972063895984
# Current Val Accuracy = 0.76611328125
# Starting epoch 100/160, LR = 0.1
# Current Avg Loss = 0.6440518697102865
# Current Val Accuracy = 0.76611328125
# Starting epoch 101/160, LR = 0.1
# Current Avg Loss = 0.6490715711544721
# Current Val Accuracy = 0.7849609375
# Starting epoch 102/160, LR = 0.1
# Current Avg Loss = 0.6350060487404848
# Current Val Accuracy = 0.76162109375
# Starting epoch 103/160, LR = 0.1
# Current Avg Loss = 0.6457833510178786
# Current Val Accuracy = 0.7849609375
# Starting epoch 104/160, LR = 0.1
# Current Avg Loss = 0.6395535102257361
# Current Val Accuracy = 0.75625
# Starting epoch 105/160, LR = 0.1
# Current Avg Loss = 0.6401435167361529
# Current Val Accuracy = 0.7833984375
# Starting epoch 106/160, LR = 0.1
# Current Avg Loss = 0.6322898864746094
# Current Val Accuracy = 0.79130859375
# Starting epoch 107/160, LR = 0.1
# Current Avg Loss = 0.6412478715945513
# Current Val Accuracy = 0.774609375
# Starting epoch 108/160, LR = 0.1
# Current Avg Loss = 0.6450909834641677
# Current Val Accuracy = 0.77890625
# Starting epoch 109/160, LR = 0.1
# Current Avg Loss = 0.6349343519944411
# Current Val Accuracy = 0.78095703125
# Starting epoch 110/160, LR = 0.1
# Current Avg Loss = 0.6276402106651893
# Current Val Accuracy = 0.77998046875
# Starting epoch 111/160, LR = 0.1
# Current Avg Loss = 0.6347644512469952
# Current Val Accuracy = 0.79169921875
# Starting epoch 112/160, LR = 0.1
# Current Avg Loss = 0.6344861739721054
# Current Val Accuracy = 0.773046875
# Starting epoch 113/160, LR = 0.1
# Current Avg Loss = 0.6331194364107572
# Current Val Accuracy = 0.77705078125
# Starting epoch 114/160, LR = 0.1
# Current Avg Loss = 0.6233313633845403
# Current Val Accuracy = 0.76533203125
# Starting epoch 115/160, LR = 0.1
# Current Avg Loss = 0.6237591963547927
# Current Val Accuracy = 0.796875
# Starting epoch 116/160, LR = 0.1
# Current Avg Loss = 0.6234451196132562
# Current Val Accuracy = 0.777734375
# Starting epoch 117/160, LR = 0.1
# Current Avg Loss = 0.6233085241073217
# Current Val Accuracy = 0.79140625
# Starting epoch 118/160, LR = 0.1
# Current Avg Loss = 0.6163096305651542
# Current Val Accuracy = 0.781640625
# Starting epoch 119/160, LR = 0.1
# Current Avg Loss = 0.6129807692307693
# Current Val Accuracy = 0.78974609375
# Starting epoch 120/160, LR = 0.1
# Current Avg Loss = 0.6217542305970803
# Current Val Accuracy = 0.7724609375
# Starting epoch 121/160, LR = 0.1
# Current Avg Loss = 0.62939697656876
# Current Val Accuracy = 0.7912109375
# Starting epoch 122/160, LR = 0.1
# Current Avg Loss = 0.6190636952718099
# Current Val Accuracy = 0.764453125
# Starting epoch 123/160, LR = 0.1
# Current Avg Loss = 0.6042390481019632
# Current Val Accuracy = 0.78408203125
# Starting epoch 124/160, LR = 0.1
# Current Avg Loss = 0.6073759030073117
# Current Val Accuracy = 0.7900390625
# Starting epoch 125/160, LR = 0.1
# Current Avg Loss = 0.6078895666660407
# Current Val Accuracy = 0.79482421875
# Starting epoch 126/160, LR = 0.1
# Current Avg Loss = 0.6096864357972757
# Current Val Accuracy = 0.78984375
# Starting epoch 127/160, LR = 0.1
# Current Avg Loss = 0.6095131116035657
# Current Val Accuracy = 0.7703125
# Starting epoch 128/160, LR = 0.1
# Current Avg Loss = 0.6093533833821615
# Current Val Accuracy = 0.7869140625
# Starting epoch 129/160, LR = 0.1
# Current Avg Loss = 0.6028177799322666
# Current Val Accuracy = 0.77841796875
# Starting epoch 130/160, LR = 0.1
# Current Avg Loss = 0.6009577237642728
# Current Val Accuracy = 0.781640625
# Starting epoch 131/160, LR = 0.1
# Current Avg Loss = 0.6025791168212891
# Current Val Accuracy = 0.78779296875
# Starting epoch 132/160, LR = 0.1
# Current Avg Loss = 0.5991920569004157
# Current Val Accuracy = 0.80546875
# Starting epoch 133/160, LR = 0.1
# Current Avg Loss = 0.5958822690523587
# Current Val Accuracy = 0.79580078125
# Starting epoch 134/160, LR = 0.1
# Current Avg Loss = 0.5953494340945513
# Current Val Accuracy = 0.79638671875
# Starting epoch 135/160, LR = 0.1
# Current Avg Loss = 0.5854344490246896
# Current Val Accuracy = 0.78896484375
# Starting epoch 136/160, LR = 0.1
# Current Avg Loss = 0.5965943458752755
# Current Val Accuracy = 0.79033203125
# Starting epoch 137/160, LR = 0.1
# Current Avg Loss = 0.5959381690392127
# Current Val Accuracy = 0.79384765625
# Starting epoch 138/160, LR = 0.1
# Current Avg Loss = 0.6051638676570013
# Current Val Accuracy = 0.78759765625
# Starting epoch 139/160, LR = 0.1
# Current Avg Loss = 0.5921513973138272
# Current Val Accuracy = 0.7849609375
# Starting epoch 140/160, LR = 0.1
# Current Avg Loss = 0.5960503602639223
# Current Val Accuracy = 0.75673828125
# Starting epoch 141/160, LR = 0.1
# Current Avg Loss = 0.590892840654422
# Current Val Accuracy = 0.75439453125
# Starting epoch 142/160, LR = 0.1
# Current Avg Loss = 0.5880884512876853
# Current Val Accuracy = 0.77841796875
# Starting epoch 143/160, LR = 0.1
# Current Avg Loss = 0.5800269689315405
# Current Val Accuracy = 0.7900390625
# Starting epoch 144/160, LR = 0.1
# Current Avg Loss = 0.5831835331060947
# Current Val Accuracy = 0.798046875
# Starting epoch 145/160, LR = 0.1
# Current Avg Loss = 0.5874923803867438
# Current Val Accuracy = 0.794921875
# Starting epoch 146/160, LR = 0.1
# Current Avg Loss = 0.5893890674297626
# Current Val Accuracy = 0.78974609375
# Starting epoch 147/160, LR = 0.1
# Current Avg Loss = 0.5865350869985727
# Current Val Accuracy = 0.79033203125
# Starting epoch 148/160, LR = 0.1
# Current Avg Loss = 0.5820582952254858
# Current Val Accuracy = 0.78740234375
# Starting epoch 149/160, LR = 0.1
# Current Avg Loss = 0.581284645276192
# Current Val Accuracy = 0.791796875
# Starting epoch 150/160, LR = 0.1
# Current Avg Loss = 0.5783325586563501
# Current Val Accuracy = 0.7884765625
# Starting epoch 151/160, LR = 0.1
# Current Avg Loss = 0.5808404286702474
# Current Val Accuracy = 0.80029296875
# Starting epoch 152/160, LR = 0.1
# Current Avg Loss = 0.5904684800368089
# Current Val Accuracy = 0.78916015625
# Starting epoch 153/160, LR = 0.1
# Current Avg Loss = 0.574091055454352
# Current Val Accuracy = 0.77470703125
# Starting epoch 154/160, LR = 0.1
# Current Avg Loss = 0.5804093189728565
# Current Val Accuracy = 0.790625
# Starting epoch 155/160, LR = 0.1
# Current Avg Loss = 0.5705845661652393
# Current Val Accuracy = 0.7953125
# Starting epoch 156/160, LR = 0.1
# Current Avg Loss = 0.5752426049648187
# Current Val Accuracy = 0.78037109375
# Starting epoch 157/160, LR = 0.1
# Current Avg Loss = 0.5823335892114884
# Current Val Accuracy = 0.792578125
# Starting epoch 158/160, LR = 0.1
# Current Avg Loss = 0.5744510063758264
# Current Val Accuracy = 0.80341796875
# Starting epoch 159/160, LR = 0.1
# Current Avg Loss = 0.562967544946915
# Current Val Accuracy = 0.80009765625
# Starting epoch 160/160, LR = 0.1
# Current Avg Loss = 0.5797750032865084
# Current Val Accuracy = 0.801953125
# Max Validation Accuracy: 0.80546875
# Test Accuracy: 0.79501953125
# Num Parameters = 2372
# Files already downloaded and verified
# Files already downloaded and verified
# Train Dataset: 40000
# Valid Dataset: 10000
# Test Dataset: 10000
# Starting epoch 1/160, LR = 0.1
# Current Avg Loss = 4.767475225986579
# Current Val Accuracy = 0.11259765625
# Starting epoch 2/160, LR = 0.1
# Current Avg Loss = 2.285302969125601
# Current Val Accuracy = 0.1525390625
# Starting epoch 3/160, LR = 0.1
# Current Avg Loss = 2.24344732822516
# Current Val Accuracy = 0.194921875
# Starting epoch 4/160, LR = 0.1
# Current Avg Loss = 2.196612235827324
# Current Val Accuracy = 0.21533203125
# Starting epoch 5/160, LR = 0.1
# Current Avg Loss = 2.1408284505208335
# Current Val Accuracy = 0.21201171875
# Starting epoch 6/160, LR = 0.1
# Current Avg Loss = 2.0799713134765625
# Current Val Accuracy = 0.249609375
# Starting epoch 7/160, LR = 0.1
# Current Avg Loss = 2.05101071871244
# Current Val Accuracy = 0.24892578125
# Starting epoch 8/160, LR = 0.1
# Current Avg Loss = 2.0212120643028846
# Current Val Accuracy = 0.26455078125
# Starting epoch 9/160, LR = 0.1
# Current Avg Loss = 1.9928614298502605
# Current Val Accuracy = 0.28974609375
# Starting epoch 10/160, LR = 0.1
# Current Avg Loss = 1.9513721955128205
# Current Val Accuracy = 0.28359375
# Starting epoch 11/160, LR = 0.1
# Current Avg Loss = 1.909327384753105
# Current Val Accuracy = 0.30341796875
# Starting epoch 12/160, LR = 0.1
# Current Avg Loss = 1.8814597496619592
# Current Val Accuracy = 0.32412109375
# Starting epoch 13/160, LR = 0.1
# Current Avg Loss = 1.8441512279021435
# Current Val Accuracy = 0.33779296875
# Starting epoch 14/160, LR = 0.1
# Current Avg Loss = 1.8233683659480169
# Current Val Accuracy = 0.35771484375
# Starting epoch 15/160, LR = 0.1
# Current Avg Loss = 1.7971449631911058
# Current Val Accuracy = 0.37080078125
# Starting epoch 16/160, LR = 0.1
# Current Avg Loss = 1.7677980080629005
# Current Val Accuracy = 0.375390625
# Starting epoch 17/160, LR = 0.1
# Current Avg Loss = 1.7467412704076521
# Current Val Accuracy = 0.38603515625
# Starting epoch 18/160, LR = 0.1
# Current Avg Loss = 1.7296209090795271
# Current Val Accuracy = 0.39697265625
# Starting epoch 19/160, LR = 0.1
# Current Avg Loss = 1.7215654422075322
# Current Val Accuracy = 0.40771484375
# Starting epoch 20/160, LR = 0.1
# Current Avg Loss = 1.6964617998172076
# Current Val Accuracy = 0.43056640625
# Starting epoch 21/160, LR = 0.1
# Current Avg Loss = 1.6871519822340746
# Current Val Accuracy = 0.42919921875
# Starting epoch 22/160, LR = 0.1
# Current Avg Loss = 1.6627989548903246
# Current Val Accuracy = 0.43408203125
# Starting epoch 23/160, LR = 0.1
# Current Avg Loss = 1.6514145288711939
# Current Val Accuracy = 0.45859375
# Starting epoch 24/160, LR = 0.1
# Current Avg Loss = 1.644076420710637
# Current Val Accuracy = 0.46259765625
# Starting epoch 25/160, LR = 0.1
# Current Avg Loss = 1.62263919145633
# Current Val Accuracy = 0.46337890625
# Starting epoch 26/160, LR = 0.1
# Current Avg Loss = 1.6021763728215144
# Current Val Accuracy = 0.47490234375
# Starting epoch 27/160, LR = 0.1
# Current Avg Loss = 1.5854539137620192
# Current Val Accuracy = 0.46962890625
# Starting epoch 28/160, LR = 0.1
# Current Avg Loss = 1.583054469181941
# Current Val Accuracy = 0.47861328125
# Starting epoch 29/160, LR = 0.1
# Current Avg Loss = 1.5648772410857372
# Current Val Accuracy = 0.4884765625
# Starting epoch 30/160, LR = 0.1
# Current Avg Loss = 1.5577939351399739
# Current Val Accuracy = 0.48486328125
# Starting epoch 31/160, LR = 0.1
# Current Avg Loss = 1.5453883440066607
# Current Val Accuracy = 0.48876953125
# Starting epoch 32/160, LR = 0.1
# Current Avg Loss = 1.5310213137895634
# Current Val Accuracy = 0.48466796875
# Starting epoch 33/160, LR = 0.1
# Current Avg Loss = 1.5175577799479167
# Current Val Accuracy = 0.496875
# Starting epoch 34/160, LR = 0.1
# Current Avg Loss = 1.5218904935396635
# Current Val Accuracy = 0.514453125
# Starting epoch 35/160, LR = 0.1
# Current Avg Loss = 1.4891624450683594
# Current Val Accuracy = 0.515234375
# Starting epoch 36/160, LR = 0.1
# Current Avg Loss = 1.484840295253656
# Current Val Accuracy = 0.513671875
# Starting epoch 37/160, LR = 0.1
# Current Avg Loss = 1.4605001791929588
# Current Val Accuracy = 0.51943359375
# Starting epoch 38/160, LR = 0.1
# Current Avg Loss = 1.452769744090545
# Current Val Accuracy = 0.51708984375
# Starting epoch 39/160, LR = 0.1
# Current Avg Loss = 1.4495171767014723
# Current Val Accuracy = 0.54638671875
# Starting epoch 40/160, LR = 0.1
# Current Avg Loss = 1.4541059640737681
# Current Val Accuracy = 0.51064453125
# Starting epoch 41/160, LR = 0.1
# Current Avg Loss = 1.4290888859675481
# Current Val Accuracy = 0.54072265625
# Starting epoch 42/160, LR = 0.1
# Current Avg Loss = 1.427086169903095
# Current Val Accuracy = 0.540234375
# Starting epoch 43/160, LR = 0.1
# Current Avg Loss = 1.4080298008062901
# Current Val Accuracy = 0.5390625
# Starting epoch 44/160, LR = 0.1
# Current Avg Loss = 1.428923582419371
# Current Val Accuracy = 0.497265625
# Starting epoch 45/160, LR = 0.1
# Current Avg Loss = 1.4109007028432994
# Current Val Accuracy = 0.544140625
# Starting epoch 46/160, LR = 0.1
# Current Avg Loss = 1.395536178197616
# Current Val Accuracy = 0.5390625
# Starting epoch 47/160, LR = 0.1
# Current Avg Loss = 1.3832331926394732
# Current Val Accuracy = 0.54873046875
# Starting epoch 48/160, LR = 0.1
# Current Avg Loss = 1.3985841213128505
# Current Val Accuracy = 0.565625
# Starting epoch 49/160, LR = 0.1
# Current Avg Loss = 1.3873523809970953
# Current Val Accuracy = 0.56259765625
# Starting epoch 50/160, LR = 0.1
# Current Avg Loss = 1.3765969887757912
# Current Val Accuracy = 0.56357421875
# Starting epoch 51/160, LR = 0.1
# Current Avg Loss = 1.3702749594663963
# Current Val Accuracy = 0.568359375
# Starting epoch 52/160, LR = 0.1
# Current Avg Loss = 1.342051285963792
# Current Val Accuracy = 0.5796875
# Starting epoch 53/160, LR = 0.1
# Current Avg Loss = 1.3549868265787761
# Current Val Accuracy = 0.55625
# Starting epoch 54/160, LR = 0.1
# Current Val Accuracy = 0.55966796875
# Starting epoch 55/160, LR = 0.1

# %% [markdown]
# ### Plot average loss and validation accuracy per epoch

# %%
epochs = [i + 1 for i in range(NUM_EPOCHS)]
_, loss_bn, acc_bn = read_stats(FILE_PATH + '/resnet20_bn/stats.csv')
_, loss_gn, acc_gn = read_stats(FILE_PATH + '/resnet20_gn/stats.csv')

filename = FILE_PATH + "/resnet20_loss"
plot_stats(x=epochs, data=[loss_bn, loss_gn], save_path=filename, title="Loss per Epoch", x_label="Epoch", y_label="Loss", data_labels=["ResNet-20 BN", "ResNet-20 GN"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(loss_bn), max(loss_gn))))

acc_bn = [100*a for a in acc_bn]
acc_gn = [100*a for a in acc_gn]
filename = FILE_PATH + "/resnet20_accuracy"
plot_stats(x=epochs, data=[acc_bn, acc_gn], save_path=filename, title="Validation Accuracy per Epoch", x_label="Epoch", y_label="Accuracy [%]", data_labels=["ResNet-20 BN", "ResNet-20 GN"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(acc_bn), max(acc_gn))))

# %%
zip_name = "/content/fedmd/baseline_public_cifar10_batch1024.zip"
# !zip -r {zip_name} /content/fedmd/baseline_public_cifar10/
# !cp {zip_name} /content/drive/MyDrive/understanding_federated_learning_project/baselines_results

# %% [markdown]
# ## Train DenseNet20 and DenseNet10

# %%
if not os.path.isdir('fedmd/baseline_public_cifar10/densenet'):
  # !mkdir fedmd/baseline_public_cifar10/densenet

  K = 12
  LR = 1e-1     
  MOMENTUM = 0.9       
  WEIGHT_DECAY = 1e-4  
  NUM_EPOCHS = 100
  FILE_PATH =  os.getcwd() + '/fedmd/baseline_public_cifar10/densenet'
  NUM_CLASSES = 10
  GROUPS = 2

  # !mkdir fedmd/baseline_public_cifar10/densenet/densenet20/
  net = DenseNet(K, 20, 1, NUM_CLASSES, False, GROUPS)
  print(f"Num Parameters = {model_size(net)}")
  train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/densenet20')

  # !mkdir fedmd/baseline_public_cifar10/densenet/densenet10/
  net = DenseNet(K, 10, 1, NUM_CLASSES, False, GROUPS)
  print(f"Num Parameters = {model_size(net)}")
  train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/densenet10')

# %% [markdown]
# ### Plot average loss and validation accuracy per epoch

# %%
epochs = [i + 1 for i in range(NUM_EPOCHS)]
_, loss_dn20, acc_dn20 = read_stats(FILE_PATH + '/densenet20/stats.csv')
_, loss_dn10, acc_dn10 = read_stats(FILE_PATH + '/densenet10/stats.csv')

filename = FILE_PATH + "/densenet_loss"
plot_stats(x=epochs, data=[loss_dn20, loss_dn10], save_path=filename, title="Loss per Epoch", x_label="Epoch", y_label="Loss", data_labels=["DenseNet-20", "DenseNet-10"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(loss_dn20), max(loss_dn10))))

acc_dn20 = [100*a for a in acc_dn20]
acc_dn10 = [100*a for a in acc_dn10]
filename = FILE_PATH + "/densenet_accuracy"
plot_stats(x=epochs, data=[acc_dn20, acc_dn10], save_path=filename, title="Validation Accuracy per Epoch", x_label="Epoch", y_label="Accuracy [%]", data_labels=["DenseNet-20", "DenseNet-10"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(acc_dn10), max(acc_dn20))))

# %%
zip_name = "/content/fedmd/baseline_public_cifar10_2.zip"
# !zip -r {zip_name} /content/fedmd/baseline_public_cifar10/
# !cp {zip_name} /content/drive/MyDrive/understanding_federated_learning_project/baselines_results

# %% [markdown]
# ## Train ShuffleNetBig and ShuffleNetSmall

# %%
if not os.path.isdir('fedmd/baseline_public_cifar10/shufflenetv2'):
  # !mkdir fedmd/baseline_public_cifar10/shufflenetv2

  LR = 1e-1     
  MOMENTUM = 0.9       
  WEIGHT_DECAY = 1e-4  
  NUM_EPOCHS = 200
  FILE_PATH =  os.getcwd() + '/fedmd/baseline_public_cifar10/shufflenetv2'
  NUM_CLASSES = 10
  GROUPS = 2

#  !mkdir fedmd/baseline_public_cifar10/shufflenetv2/shufflenetbig/
#  stages_repeats = [4, 8, 4]
#  stages_out_channels = [32, 64, 128, 256, 512]
#  net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)
#  print(f"Num Parameters = {model_size(net)}")
#  train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/shufflenetbig')

  # !mkdir fedmd/baseline_public_cifar10/shufflenetv2/shufflenetsmall/
  stages_repeats = [2, 4, 2]
  stages_out_channels = [16, 32, 64, 128, 256]
  net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)
  print(f"Num Parameters = {model_size(net)}")
  train_on_cifar(net, NUM_EPOCHS, LR, MOMENTUM, WEIGHT_DECAY, cifar_100=False, file_path=FILE_PATH + '/shufflenetsmall')
# Out:
# Num Parameters = 4100
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:12<00:00, 13240735.33it/s]
# Extracting /content/cifar-10-python.tar.gz to /content
# Files already downloaded and verified
# Train Dataset: 40000
# Valid Dataset: 10000
# Test Dataset: 10000
# Starting epoch 1/200, LR = 0.1
# Current Avg Loss = 2.0584918291140823
# Current Val Accuracy = 0.30063291139240506
# Starting epoch 2/200, LR = 0.1
# Current Avg Loss = 1.8754871074969952
# Current Val Accuracy = 0.33860759493670883
# Starting epoch 3/200, LR = 0.1
# Current Avg Loss = 1.8070706098507612
# Current Val Accuracy = 0.4017998417721519
# Starting epoch 4/200, LR = 0.1
# Current Avg Loss = 1.7620254907852564
# Current Val Accuracy = 0.41356803797468356
# Starting epoch 5/200, LR = 0.1
# Current Avg Loss = 1.7282313811473358
# Current Val Accuracy = 0.4464003164556962
# Starting epoch 6/200, LR = 0.1
# Current Avg Loss = 1.683744381635617
# Current Val Accuracy = 0.44096123417721517
# Starting epoch 7/200, LR = 0.1
# Current Avg Loss = 1.669042733999399
# Current Val Accuracy = 0.4639042721518987
# Starting epoch 8/200, LR = 0.1
# Current Avg Loss = 1.6361600435697115
# Current Val Accuracy = 0.4799248417721519
# Starting epoch 9/200, LR = 0.1
# Current Avg Loss = 1.6231653262407353
# Current Val Accuracy = 0.49020965189873417
# Starting epoch 10/200, LR = 0.1
# Current Avg Loss = 1.6067019731570513
# Current Val Accuracy = 0.48180379746835444
# Starting epoch 11/200, LR = 0.1
# Current Avg Loss = 1.5841607313889723
# Current Val Accuracy = 0.49564873417721517
# Starting epoch 12/200, LR = 0.1
# Current Avg Loss = 1.5607719421386719
# Current Val Accuracy = 0.521064082278481
# Starting epoch 13/200, LR = 0.1
# Current Avg Loss = 1.5362023573655348
# Current Val Accuracy = 0.5169106012658228
# Starting epoch 14/200, LR = 0.1
# Current Avg Loss = 1.5290353237054286
# Current Val Accuracy = 0.5000988924050633
# Starting epoch 15/200, LR = 0.1
# Current Avg Loss = 1.516436552390074
# Current Val Accuracy = 0.5147349683544303
# Starting epoch 16/200, LR = 0.1
# Current Avg Loss = 1.5032283098269732
# Current Val Accuracy = 0.5388647151898734
# Starting epoch 17/200, LR = 0.1
# Current Avg Loss = 1.4983818836701221
# Current Val Accuracy = 0.530557753164557
# Starting epoch 18/200, LR = 0.1
# Current Avg Loss = 1.4775555928548176
# Current Val Accuracy = 0.5039556962025317
# Starting epoch 19/200, LR = 0.1
# Current Avg Loss = 1.4785851698655348
# Current Val Accuracy = 0.5183939873417721
# Starting epoch 20/200, LR = 0.1
# Current Avg Loss = 1.4702325478578224
# Current Val Accuracy = 0.5325356012658228
# Starting epoch 21/200, LR = 0.1
# Current Avg Loss = 1.4554866888584235
# Current Val Accuracy = 0.5506329113924051
# Starting epoch 22/200, LR = 0.1
# Current Avg Loss = 1.4545811384152143
# Current Val Accuracy = 0.5275909810126582
# Starting epoch 23/200, LR = 0.1
# Current Avg Loss = 1.4399422865647535
# Current Val Accuracy = 0.5443037974683544
# Starting epoch 24/200, LR = 0.1
# Current Avg Loss = 1.4320615132649739
# Current Val Accuracy = 0.552314082278481
# Starting epoch 25/200, LR = 0.1
# Current Avg Loss = 1.4287920242700822
# Current Val Accuracy = 0.5450949367088608
# Starting epoch 26/200, LR = 0.1
# Current Avg Loss = 1.4240216964330428
# Current Val Accuracy = 0.5787183544303798
# Starting epoch 27/200, LR = 0.1
# Current Avg Loss = 1.4075381939227765
# Current Val Accuracy = 0.5716969936708861
# Starting epoch 28/200, LR = 0.1
# Current Avg Loss = 1.4123097933255708
# Current Val Accuracy = 0.555379746835443
# Starting epoch 29/200, LR = 0.1
# Current Avg Loss = 1.408877446101262
# Current Val Accuracy = 0.5362935126582279
# Starting epoch 30/200, LR = 0.1
# Current Avg Loss = 1.3920834859212239
# Current Val Accuracy = 0.5744659810126582
# Starting epoch 31/200, LR = 0.1
# Current Avg Loss = 1.3889380234938402
# Current Val Accuracy = 0.5797072784810127
# Starting epoch 32/200, LR = 0.1
# Current Avg Loss = 1.3836663074982471
# Current Val Accuracy = 0.5614121835443038
# Starting epoch 33/200, LR = 0.1
# Current Avg Loss = 1.3831339126978166
# Current Val Accuracy = 0.5527096518987342
# Starting epoch 34/200, LR = 0.1
# Current Avg Loss = 1.379487062111879
# Current Val Accuracy = 0.5528085443037974
# Starting epoch 35/200, LR = 0.1
# Current Avg Loss = 1.3688922784267328
# Current Val Accuracy = 0.559434335443038
# Starting epoch 36/200, LR = 0.1
# Current Avg Loss = 1.3674732110439203
# Current Val Accuracy = 0.551621835443038
# Starting epoch 37/200, LR = 0.1
# Current Avg Loss = 1.3645625970302484
# Current Val Accuracy = 0.5909810126582279
# Starting epoch 38/200, LR = 0.1
# Current Avg Loss = 1.3522447439340444
# Current Val Accuracy = 0.5925632911392406
# Starting epoch 39/200, LR = 0.1
# Current Avg Loss = 1.3414995242387822
# Current Val Accuracy = 0.5789161392405063
# Starting epoch 40/200, LR = 0.1
# Current Avg Loss = 1.3475758479191706
# Current Val Accuracy = 0.5664556962025317
# Starting epoch 41/200, LR = 0.1
# Current Avg Loss = 1.3392606881948619
# Current Val Accuracy = 0.5647745253164557
# Starting epoch 42/200, LR = 0.1
# Current Avg Loss = 1.342117896446815
# Current Val Accuracy = 0.5621044303797469
# Starting epoch 43/200, LR = 0.1
# Current Avg Loss = 1.3529768723707933
# Current Val Accuracy = 0.5900909810126582
# Starting epoch 44/200, LR = 0.1
# Current Avg Loss = 1.331642835568159
# Current Val Accuracy = 0.5877175632911392
# Starting epoch 45/200, LR = 0.1
# Current Avg Loss = 1.3334302657689803
# Current Val Accuracy = 0.5813884493670886
# Starting epoch 46/200, LR = 0.1
# Current Avg Loss = 1.3211603409204729
# Current Val Accuracy = 0.6052215189873418
# Starting epoch 47/200, LR = 0.1
# Current Avg Loss = 1.3289673634064503
# Current Val Accuracy = 0.595431170886076
# Starting epoch 48/200, LR = 0.1
# Current Avg Loss = 1.3152429629594853
# Current Val Accuracy = 0.612440664556962
# Starting epoch 49/200, LR = 0.1
# Current Avg Loss = 1.3086272997733874
# Current Val Accuracy = 0.608682753164557
# Starting epoch 50/200, LR = 0.1
# Current Avg Loss = 1.319808568709936
# Current Val Accuracy = 0.5755537974683544
# Starting epoch 51/200, LR = 0.1
# Current Avg Loss = 1.3193995157877605
# Current Val Accuracy = 0.5818829113924051
# Starting epoch 52/200, LR = 0.1
# Current Avg Loss = 1.3205838325696113
# Current Val Accuracy = 0.5669501582278481
# Starting epoch 53/200, LR = 0.1
# Current Avg Loss = 1.3103856795873396
# Current Val Accuracy = 0.6030458860759493
# Starting epoch 54/200, LR = 0.1
# Current Avg Loss = 1.3102486439240284
# Current Val Accuracy = 0.6058148734177216
# Starting epoch 55/200, LR = 0.1
# Current Avg Loss = 1.2976564260629506
# Current Val Accuracy = 0.6072982594936709
# Starting epoch 56/200, LR = 0.1
# Current Avg Loss = 1.293875474196214
# Current Val Accuracy = 0.5929588607594937
# Starting epoch 57/200, LR = 0.1
# Current Avg Loss = 1.299761747702574
# Current Val Accuracy = 0.5979034810126582
# Starting epoch 58/200, LR = 0.1
# Current Avg Loss = 1.2843377529046474
# Current Val Accuracy = 0.5939477848101266
# Starting epoch 59/200, LR = 0.1
# Current Avg Loss = 1.292862818791316
# Current Val Accuracy = 0.6109572784810127
# Starting epoch 60/200, LR = 0.1
# Current Avg Loss = 1.2928868807279146
# Current Val Accuracy = 0.5854430379746836
# Starting epoch 61/200, LR = 0.1
# Current Avg Loss = 1.2921220828325322
# Current Val Accuracy = 0.5861352848101266
# Starting epoch 62/200, LR = 0.1
# Current Avg Loss = 1.2894386878380408
# Current Val Accuracy = 0.608682753164557
# Starting epoch 63/200, LR = 0.1
# Current Avg Loss = 1.2700025118314302
# Current Val Accuracy = 0.6157041139240507
# Starting epoch 64/200, LR = 0.1
# Current Avg Loss = 1.2802500602526543
# Current Val Accuracy = 0.575751582278481
# Starting epoch 65/200, LR = 0.1
# Current Avg Loss = 1.2790115552070813
# Current Val Accuracy = 0.6050237341772152
# Starting epoch 66/200, LR = 0.1
# Current Avg Loss = 1.2749832348945813
# Current Val Accuracy = 0.6143196202531646
# Starting epoch 67/200, LR = 0.1
# Current Avg Loss = 1.2683481069711537
# Current Val Accuracy = 0.6006724683544303
# Starting epoch 68/200, LR = 0.1
# Current Avg Loss = 1.2684731116661658
# Current Val Accuracy = 0.5951344936708861
# Starting epoch 69/200, LR = 0.1
# Current Avg Loss = 1.264761704664964
# Current Val Accuracy = 0.5934533227848101
# Starting epoch 70/200, LR = 0.1
# Current Avg Loss = 1.2664991525503306
# Current Val Accuracy = 0.6257911392405063
# Starting epoch 71/200, LR = 0.1
# Current Avg Loss = 1.2694965264736078
# Current Val Accuracy = 0.6151107594936709
# Starting epoch 72/200, LR = 0.1
# Current Avg Loss = 1.270283430050581
# Current Val Accuracy = 0.6216376582278481
# Starting epoch 73/200, LR = 0.1
# Current Avg Loss = 1.2569263164813702
# Current Val Accuracy = 0.5996835443037974
# Starting epoch 74/200, LR = 0.1
# Current Avg Loss = 1.2613766009990985
# Current Val Accuracy = 0.6001780063291139
# Starting epoch 75/200, LR = 0.1
# Current Avg Loss = 1.2562205974872296
# Current Val Accuracy = 0.6065071202531646
# Starting epoch 76/200, LR = 0.1
# Current Avg Loss = 1.2550202394143128
# Current Val Accuracy = 0.627373417721519
# Starting epoch 77/200, LR = 0.1
# Current Avg Loss = 1.2552203643016326
# Current Val Accuracy = 0.6272745253164557
# Starting epoch 78/200, LR = 0.1
# Current Avg Loss = 1.252889682085086
# Current Val Accuracy = 0.6121439873417721
# Starting epoch 79/200, LR = 0.1
# Current Avg Loss = 1.24998532808744
# Current Val Accuracy = 0.599881329113924
# Starting epoch 80/200, LR = 0.1
# Current Avg Loss = 1.2447403149727063
# Current Val Accuracy = 0.6149129746835443
# Starting epoch 81/200, LR = 0.1
# Current Avg Loss = 1.2572899842873597
# Current Val Accuracy = 0.6282634493670886
# Starting epoch 82/200, LR = 0.1
# Current Avg Loss = 1.250455611791366
# Current Val Accuracy = 0.5839596518987342
# Starting epoch 83/200, LR = 0.1
# Current Avg Loss = 1.2551706754244292
# Current Val Accuracy = 0.6010680379746836
# Starting epoch 84/200, LR = 0.1
# Current Avg Loss = 1.2430211580716646
# Current Val Accuracy = 0.6203520569620253
# Starting epoch 85/200, LR = 0.1
# Current Avg Loss = 1.2431691487630208
# Current Val Accuracy = 0.5880142405063291
# Starting epoch 86/200, LR = 0.1
# Current Avg Loss = 1.2477066822541065
# Current Val Accuracy = 0.6146162974683544
# Starting epoch 87/200, LR = 0.1
# Current Avg Loss = 1.2314762213291266
# Current Val Accuracy = 0.5996835443037974
# Starting epoch 88/200, LR = 0.1
# Current Avg Loss = 1.2369649838178585
# Current Val Accuracy = 0.6387460443037974
# Starting epoch 89/200, LR = 0.1
# Current Avg Loss = 1.2347796513484075
# Current Val Accuracy = 0.6204509493670886
# Starting epoch 90/200, LR = 0.1
# Current Avg Loss = 1.2412931002103365
# Current Val Accuracy = 0.6168908227848101
# Starting epoch 91/200, LR = 0.1
# Current Avg Loss = 1.2337642571864984
# Current Val Accuracy = 0.6376582278481012
# Starting epoch 92/200, LR = 0.1
# Current Avg Loss = 1.231206551576272
# Current Val Accuracy = 0.6194620253164557
# Starting epoch 93/200, LR = 0.1
# Current Avg Loss = 1.2380657685108674
# Current Val Accuracy = 0.6262856012658228
# Starting epoch 94/200, LR = 0.1
# Current Avg Loss = 1.2399278298402443
# Current Val Accuracy = 0.6143196202531646
# Starting epoch 95/200, LR = 0.1
# Current Avg Loss = 1.2351007706079729
# Current Val Accuracy = 0.6173852848101266
# Starting epoch 96/200, LR = 0.1
# Current Avg Loss = 1.2254534012232072
# Current Val Accuracy = 0.6214398734177216
# Starting epoch 97/200, LR = 0.1
# Current Avg Loss = 1.2276604481232471
# Current Val Accuracy = 0.6153085443037974
# Starting epoch 98/200, LR = 0.1
# Current Avg Loss = 1.2325599866035657
# Current Val Accuracy = 0.5896954113924051
# Starting epoch 99/200, LR = 0.1
# Current Avg Loss = 1.2229126172188
# Current Val Accuracy = 0.6229232594936709
# Starting epoch 100/200, LR = 0.1
# Current Avg Loss = 1.229049291366186
# Current Val Accuracy = 0.6053204113924051
# Starting epoch 101/200, LR = 0.1
# Current Avg Loss = 1.230127481313852
# Current Val Accuracy = 0.6383504746835443
# Starting epoch 102/200, LR = 0.1
# Current Avg Loss = 1.2167721283741486
# Current Val Accuracy = 0.6159018987341772
# Starting epoch 103/200, LR = 0.1
# Current Avg Loss = 1.2135950724283855
# Current Val Accuracy = 0.625692246835443
# Starting epoch 104/200, LR = 0.1
# Current Avg Loss = 1.229578360533103
# Current Val Accuracy = 0.6160996835443038
# Starting epoch 105/200, LR = 0.1
# Current Avg Loss = 1.2224600376226964
# Current Val Accuracy = 0.6275712025316456
# Starting epoch 106/200, LR = 0.1
# Current Avg Loss = 1.2179644658015325
# Current Val Accuracy = 0.6075949367088608
# Starting epoch 107/200, LR = 0.1
# Current Avg Loss = 1.2156761365059094
# Current Val Accuracy = 0.6203520569620253
# Starting epoch 108/200, LR = 0.1
# Current Avg Loss = 1.2172943506485376
# Current Val Accuracy = 0.6324169303797469
# Starting epoch 109/200, LR = 0.1
# Current Avg Loss = 1.2197464184883313
# Current Val Accuracy = 0.6227254746835443
# Starting epoch 110/200, LR = 0.1
# Current Avg Loss = 1.2080766726762822
# Current Val Accuracy = 0.6291534810126582
# Starting epoch 111/200, LR = 0.1
# Current Avg Loss = 1.2156554002028246
# Current Val Accuracy = 0.6457674050632911
# Starting epoch 112/200, LR = 0.1
# Current Avg Loss = 1.2138636662409856
# Current Val Accuracy = 0.6363726265822784
# Starting epoch 113/200, LR = 0.1
# Current Avg Loss = 1.2231196868113983
# Current Val Accuracy = 0.620253164556962
# Starting epoch 114/200, LR = 0.1
# Current Avg Loss = 1.2094202286157854
# Current Val Accuracy = 0.6232199367088608
# Starting epoch 115/200, LR = 0.1
# Current Avg Loss = 1.210240975404397
# Current Val Accuracy = 0.6400316455696202
# Starting epoch 116/200, LR = 0.1
# Current Avg Loss = 1.2128821152907152
# Current Val Accuracy = 0.6205498417721519
# Starting epoch 117/200, LR = 0.1
# Current Avg Loss = 1.1948211865547376
# Current Val Accuracy = 0.6426028481012658
# Starting epoch 118/200, LR = 0.1
# Current Avg Loss = 1.2135501763759515
# Current Val Accuracy = 0.6203520569620253
# Starting epoch 119/200, LR = 0.1
# Current Avg Loss = 1.2101715283516126
# Current Val Accuracy = 0.6448773734177216
# Starting epoch 120/200, LR = 0.1
# Current Avg Loss = 1.1988948919834235
# Current Val Accuracy = 0.6312302215189873
# Starting epoch 121/200, LR = 0.1
# Current Avg Loss = 1.202295645689353
# Current Val Accuracy = 0.6428006329113924
# Starting epoch 122/200, LR = 0.1
# Current Avg Loss = 1.205530508970603
# Current Val Accuracy = 0.6387460443037974
# Starting epoch 123/200, LR = 0.1
# Current Avg Loss = 1.2131800529284356
# Current Val Accuracy = 0.5901898734177216
# Starting epoch 124/200, LR = 0.1
# Current Avg Loss = 1.2061853653345354
# Current Val Accuracy = 0.6225276898734177
# Starting epoch 125/200, LR = 0.1
# Current Avg Loss = 1.204363994109325
# Current Val Accuracy = 0.6341969936708861
# Starting epoch 126/200, LR = 0.1
# Current Avg Loss = 1.212796137883113
# Current Val Accuracy = 0.6472507911392406
# Starting epoch 127/200, LR = 0.1
# Current Avg Loss = 1.2043642875475762
# Current Val Accuracy = 0.6476463607594937
# Starting epoch 128/200, LR = 0.1
# Current Avg Loss = 1.1988369868351862
# Current Val Accuracy = 0.6272745253164557
# Starting epoch 129/200, LR = 0.1
# Current Avg Loss = 1.1956892747145433
# Current Val Accuracy = 0.6342958860759493
# Starting epoch 130/200, LR = 0.1
# Current Avg Loss = 1.210968506641877
# Current Val Accuracy = 0.6427017405063291
# Starting epoch 131/200, LR = 0.1
# Current Avg Loss = 1.2082249568058894
# Current Val Accuracy = 0.6388449367088608
# Starting epoch 132/200, LR = 0.1
# Current Avg Loss = 1.1935018881773338
# Current Val Accuracy = 0.6415150316455697
# Starting epoch 133/200, LR = 0.1
# Current Avg Loss = 1.190188481257512
# Current Val Accuracy = 0.6142207278481012
# Starting epoch 134/200, LR = 0.1
# Current Avg Loss = 1.2007995018592248
# Current Val Accuracy = 0.6372626582278481
# Starting epoch 135/200, LR = 0.1
# Current Avg Loss = 1.2011888944185698
# Current Val Accuracy = 0.6373615506329114
# Starting epoch 136/200, LR = 0.1
# Current Avg Loss = 1.2000680581117287
# Current Val Accuracy = 0.6417128164556962
# Starting epoch 137/200, LR = 0.1
# Current Avg Loss = 1.193129417223808
# Current Val Accuracy = 0.6407238924050633
# Starting epoch 138/200, LR = 0.1
# Current Avg Loss = 1.1887328319060497
# Current Val Accuracy = 0.6393393987341772
# Starting epoch 139/200, LR = 0.1
# Current Avg Loss = 1.2041974189953926
# Current Val Accuracy = 0.6242088607594937
# Starting epoch 140/200, LR = 0.1
# Current Avg Loss = 1.1949261396359174
# Current Val Accuracy = 0.6380537974683544
# Starting epoch 141/200, LR = 0.1
# Current Avg Loss = 1.1940308595315003
# Current Val Accuracy = 0.6286590189873418
# Starting epoch 142/200, LR = 0.1
# Current Avg Loss = 1.1881218934670472
# Current Val Accuracy = 0.6435917721518988
# Starting epoch 143/200, LR = 0.1
# Current Avg Loss = 1.1968302604479668
# Current Val Accuracy = 0.6285601265822784
# Starting epoch 144/200, LR = 0.1
# Current Avg Loss = 1.2042377178485577
# Current Val Accuracy = 0.6376582278481012
# Starting epoch 145/200, LR = 0.1
# Current Avg Loss = 1.1938473628117487
# Current Val Accuracy = 0.6313291139240507
# Starting epoch 146/200, LR = 0.1
# Current Avg Loss = 1.184903071476863
# Current Val Accuracy = 0.6411194620253164
# Starting epoch 147/200, LR = 0.1
# Current Avg Loss = 1.1893879817082331
# Current Val Accuracy = 0.6320213607594937
# Starting epoch 148/200, LR = 0.1
# Current Avg Loss = 1.1847822727301183
# Current Val Accuracy = 0.6465585443037974
# Starting epoch 149/200, LR = 0.1
# Current Avg Loss = 1.197957258958083
# Current Val Accuracy = 0.6503164556962026
# Starting epoch 150/200, LR = 0.1
# Current Avg Loss = 1.1980159466083233
# Current Val Accuracy = 0.6363726265822784
# Starting epoch 151/200, LR = 0.1
# Current Avg Loss = 1.1905794388208635
# Current Val Accuracy = 0.6135284810126582
# Starting epoch 152/200, LR = 0.1
# Current Avg Loss = 1.19251955472506
# Current Val Accuracy = 0.6558544303797469
# Starting epoch 153/200, LR = 0.1
# Current Avg Loss = 1.1960368034167168
# Current Val Accuracy = 0.5959256329113924
# Starting epoch 154/200, LR = 0.1
# Current Avg Loss = 1.185148679293119
# Current Val Accuracy = 0.6408227848101266
# Starting epoch 155/200, LR = 0.1
# Current Avg Loss = 1.1832283215645032
# Current Val Accuracy = 0.6339003164556962
# Starting epoch 156/200, LR = 0.1
# Current Avg Loss = 1.18145996485001
# Current Val Accuracy = 0.6509098101265823
# Starting epoch 157/200, LR = 0.1
# Current Avg Loss = 1.1835723290076623
# Current Val Accuracy = 0.6295490506329114
# Starting epoch 158/200, LR = 0.1
# Current Avg Loss = 1.187932821420523
# Current Val Accuracy = 0.6502175632911392
# Starting epoch 159/200, LR = 0.1
# Current Avg Loss = 1.1816477653307793
# Current Val Accuracy = 0.6554588607594937
# Starting epoch 160/200, LR = 0.1
# Current Avg Loss = 1.1801283420660558
# Current Val Accuracy = 0.6404272151898734
# Starting epoch 161/200, LR = 0.1
# Current Avg Loss = 1.1716585403833635
# Current Val Accuracy = 0.6298457278481012
# Starting epoch 162/200, LR = 0.1
# Current Avg Loss = 1.1767168289575822
# Current Val Accuracy = 0.6337025316455697
# Starting epoch 163/200, LR = 0.1
# Current Avg Loss = 1.186123285538111
# Current Val Accuracy = 0.6203520569620253
# Starting epoch 164/200, LR = 0.1
# Current Avg Loss = 1.1765310825445714
# Current Val Accuracy = 0.6493275316455697
# Starting epoch 165/200, LR = 0.1
# Current Avg Loss = 1.1905211424216247
# Current Val Accuracy = 0.6329113924050633
# Starting epoch 166/200, LR = 0.1
# Current Avg Loss = 1.1770210266113281
# Current Val Accuracy = 0.6526898734177216
# Starting epoch 167/200, LR = 0.1
# Current Avg Loss = 1.1859112274952424
# Current Val Accuracy = 0.6312302215189873
# Starting epoch 168/200, LR = 0.1
# Current Avg Loss = 1.17682618361253
# Current Val Accuracy = 0.6640625
# Starting epoch 169/200, LR = 0.1
# Current Avg Loss = 1.181611574613131
# Current Val Accuracy = 0.6451740506329114
# Starting epoch 170/200, LR = 0.1
# Current Avg Loss = 1.170208955422426
# Current Val Accuracy = 0.6408227848101266
# Starting epoch 171/200, LR = 0.1
# Current Avg Loss = 1.165716024545523
# Current Val Accuracy = 0.6331091772151899
# Starting epoch 172/200, LR = 0.1
# Current Avg Loss = 1.1712796137883112
# Current Val Accuracy = 0.6523931962025317
# Starting epoch 173/200, LR = 0.1
# Current Avg Loss = 1.1816306480994592
# Current Val Accuracy = 0.6455696202531646
# Starting epoch 174/200, LR = 0.1
# Current Avg Loss = 1.1633256765512319
# Current Val Accuracy = 0.6563488924050633
# Starting epoch 175/200, LR = 0.1
# Current Avg Loss = 1.1741788815229366
# Current Val Accuracy = 0.6362737341772152
# Starting epoch 176/200, LR = 0.1
# Current Avg Loss = 1.170275370279948
# Current Val Accuracy = 0.6378560126582279
# Starting epoch 177/200, LR = 0.1
# Current Avg Loss = 1.1756871541341145
# Current Val Accuracy = 0.6610957278481012
# Starting epoch 178/200, LR = 0.1
# Current Avg Loss = 1.1703982230944512
# Current Val Accuracy = 0.6261867088607594
# Starting epoch 179/200, LR = 0.1
# Current Avg Loss = 1.1673868619478667
# Current Val Accuracy = 0.6540743670886076
# Starting epoch 180/200, LR = 0.1
# Current Avg Loss = 1.1836768908378406
# Current Val Accuracy = 0.6397349683544303
# Starting epoch 181/200, LR = 0.1
# Current Avg Loss = 1.1747759305513823
# Current Val Accuracy = 0.6594145569620253
# Starting epoch 182/200, LR = 0.1
# Current Avg Loss = 1.1812510368151543
# Current Val Accuracy = 0.666435917721519
# Starting epoch 183/200, LR = 0.1
# Current Avg Loss = 1.1672269381009615
# Current Val Accuracy = 0.6213409810126582
# Starting epoch 184/200, LR = 0.1
# Current Avg Loss = 1.1684077336237981
# Current Val Accuracy = 0.653184335443038
# Starting epoch 185/200, LR = 0.1
# Current Avg Loss = 1.1595842410356572
# Current Val Accuracy = 0.6518987341772152
# Starting epoch 186/200, LR = 0.1
# Current Avg Loss = 1.1685493664863782
# Current Val Accuracy = 0.6355814873417721
# Starting epoch 187/200, LR = 0.1
# Current Avg Loss = 1.1640372643103967
# Current Val Accuracy = 0.6488330696202531
# Starting epoch 188/200, LR = 0.1
# Current Avg Loss = 1.1638076977852063
# Current Val Accuracy = 0.6639636075949367
# Starting epoch 189/200, LR = 0.1
# Current Avg Loss = 1.1668579884064503
# Current Val Accuracy = 0.6510087025316456
# Starting epoch 190/200, LR = 0.1
# Current Avg Loss = 1.157474126571264
# Current Val Accuracy = 0.6359770569620253
# Starting epoch 191/200, LR = 0.1
# Current Avg Loss = 1.1625414139185197
# Current Val Accuracy = 0.650118670886076
# Starting epoch 192/200, LR = 0.1
# Current Avg Loss = 1.163651099571815
# Current Val Accuracy = 0.6591178797468354
# Starting epoch 193/200, LR = 0.1
# Current Avg Loss = 1.1617834629156651
# Current Val Accuracy = 0.6620846518987342
# Starting epoch 194/200, LR = 0.1
# Current Avg Loss = 1.1568995744754107
# Current Val Accuracy = 0.6594145569620253
# Starting epoch 195/200, LR = 0.1
# Current Avg Loss = 1.1607426374386518
# Current Val Accuracy = 0.6546677215189873
# Starting epoch 196/200, LR = 0.1
# Current Avg Loss = 1.1636405357947717
# Current Val Accuracy = 0.6627768987341772
# Starting epoch 197/200, LR = 0.1
# Current Avg Loss = 1.1605101365309496
# Current Val Accuracy = 0.6583267405063291
# Starting epoch 198/200, LR = 0.1
# Current Avg Loss = 1.1621425335223858
# Current Val Accuracy = 0.6446795886075949
# Starting epoch 199/200, LR = 0.1
# Current Avg Loss = 1.1541566115159254
# Current Val Accuracy = 0.6425039556962026
# Starting epoch 200/200, LR = 0.1
# Current Avg Loss = 1.147013444166917
# Current Val Accuracy = 0.6373615506329114
# Max Validation Accuracy: 0.666435917721519
# Test Accuracy: 0.6607990506329114

# %% [markdown]
# ### Plot average loss and validation accuracy per epoch

# %%
epochs = [i + 1 for i in range(NUM_EPOCHS)]
_, loss_snb, acc_snb = read_stats(FILE_PATH + '/shufflenetbig/stats.csv')
_, loss_sns, acc_sns = read_stats(FILE_PATH + '/shufflenetsmall/stats.csv')

filename = FILE_PATH + "/shufflenet_loss"
plot_stats(x=epochs, data=[loss_snb, loss_sns], save_path=filename, title="Loss per Epoch", x_label="Epoch", y_label="Loss", data_labels=["ShuffleNet-Big", "ShuffleNet-Small"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(loss_snb), max(loss_sns))))

acc_snb = [100*a for a in acc_snb]
acc_sns = [100*a for a in acc_sns]
filename = FILE_PATH + "/shufflenet_accuracy"
plot_stats(x=epochs, data=[acc_snb, acc_sns], save_path=filename, title="Validation Accuracy per Epoch", x_label="Epoch", y_label="Accuracy [%]", data_labels=["ShuffleNet-Big", "ShuffleNet-Small"], x_lim=(1, NUM_EPOCHS), y_lim=(0, max(max(acc_snb), max(acc_sns))))

# %%
zip_name = "/content/fedmd/baseline_public_cifar10_3.zip"
# !zip -r {zip_name} /content/fedmd/baseline_public_cifar10/
# !cp {zip_name} /content/drive/MyDrive/understanding_federated_learning_project/baselines_results
# Out:
#   adding: content/fedmd/baseline_public_cifar10/ (stored 0%)
#   adding: content/fedmd/baseline_public_cifar10/shufflenetv2/ (stored 0%)
#   adding: content/fedmd/baseline_public_cifar10/shufflenetv2/shufflenetsmall/ (stored 0%)
#   adding: content/fedmd/baseline_public_cifar10/shufflenetv2/shufflenetsmall/stats.csv (deflated 58%)
#   adding: content/fedmd/baseline_public_cifar10/shufflenetv2/shufflenetsmall/best_model.pth (deflated 14%)
