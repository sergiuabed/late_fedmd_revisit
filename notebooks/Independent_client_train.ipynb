# %% [markdown]
# # Setup

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install required libraries

# %%
# !pip3 install 'torch'
# !pip3 install 'torchvision'
# !pip3 install 'pillow'
# !pip3 install 'tqdm'
# !pip3 install 'matplotlib'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.0+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision) (16.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0->torchvision) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Clone the GitHub repository

# %%
import os

if not os.path.isdir('fedmd'):
  # !git clone https://github.com/sergiuabed/fedmd
  # %cd fedmd/
  # !git checkout experiment
  # %cd ..
else:
  # %cd fedmd/
  # !git pull origin
  # %cd ..

if not os.path.isdir('fedmd/baselines_public_cifar10'):
  # !mkdir fedmd/baselines_public_cifar10
# Out:
# Cloning into 'fedmd'...
# remote: Enumerating objects: 2472, done.
# remote: Counting objects: 100% (347/347), done.
# remote: Compressing objects: 100% (322/322), done.
# remote: Total 2472 (delta 26), reused 344 (delta 23), pack-reused 2125
# Receiving objects: 100% (2472/2472), 403.74 MiB | 24.53 MiB/s, done.
# Resolving deltas: 100% (790/790), done.
# /content/fedmd
# Updating files: 100% (416/416), done.
# Branch 'experiment' set up to track remote branch 'experiment' from 'origin'.
# Switched to a new branch 'experiment'
# /content

# %% [markdown]
# ## Import libraries

# %%
from fedmd.models_implementations.resnet import ResNet
from fedmd.models_implementations.densenet import DenseNet
from fedmd.models_implementations.shufflenetv2 import ShuffleNetV2
from fedmd.models_implementations.utils import model_size, plot_stats
from fedmd.models_implementations.train_on_cifar import train_on_cifar
from fedmd.data_utils import read_data_splits
from fedmd.client.private_dataloader import ClientPrivateDataset
from torch.utils.data import DataLoader
from fedmd.client.client import Client

# %% [markdown]
# # Train each client on their respective private data
# Each client has as private dataset a subset of CIFAR100. The subsets are defined based on Dirichlet distribution which takes an input ALPHA. For vey low ALPHA, the subsets are non-IID.

# %% [markdown]
# ## Load CIFAR100 locally

# %%
# %cd fedmd/data
# !chmod +x setup_datasets.sh
# !./setup_datasets.sh
# %cd ../..
# Out:
# /content/fedmd/data
# Downloading CIFAR100...
# --2023-05-10 23:42:49--  https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169001437 (161M) [application/x-gzip]
# Saving to: ‘cifar-100-python.tar.gz’
#
# cifar-100-python.ta 100%[===================>] 161.17M  79.5MB/s    in 2.0s
#
# 2023-05-10 23:42:51 (79.5 MB/s) - ‘cifar-100-python.tar.gz’ saved [169001437/169001437]
#
# cifar-100-python/
# cifar-100-python/file.txt~
# cifar-100-python/train
# cifar-100-python/test
# cifar-100-python/meta
# Extracting images for pickle files...
# #### Setting up CIFAR100 ####
# Saving train images...
# 50000it [00:31, 1578.11it/s]
# Saving test images...
# 10000it [00:07, 1382.98it/s]
# /content

# %% [markdown]
# ## Define hyperparameters
# This cell defines the hyperparameters for each architecture

# %%
LR = 1e-1     
MOMENTUM = 0.9       
WEIGHT_DECAY = 1e-4  
NUM_EPOCHS = 30
NUM_CLASSES = 10
GROUPS = 2

#ResNet
LAYERS = [3, 3, 3]
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/resnet20'

#DenseNet
K = 12
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/densenet'

#ShuffleNet
FILE_PATH =  os.getcwd() + '/fedmd/baselines_public_cifar10/shufflenetv2'
STAGES_REPEATS_BIG = [4, 8, 4]
STAGES_OUT_CHANNELS_BIG = [32, 64, 128, 256, 512]
STAGES_REPEATS_SMALL = [2, 4, 2]
STAGES_OUT_CHANNELS_SMALL = [16, 32, 64, 128, 256]

RESNET20_BN_PARAMS = [LAYERS, NUM_CLASSES] #net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES)
RESNET20_GN_PARAMS = [LAYERS, NUM_CLASSES, "gn", GROUPS] #net = ResNet(layers = LAYERS, num_classes = NUM_CLASSES, norm_layer="gn", groups=GROUPS)

DENSENET10_PARAMS = [K, 10, 1, NUM_CLASSES, False, GROUPS]  #net = DenseNet(K, 10, 1, NUM_CLASSES, False, GROUPS)
DENSENET20_PARAMS = [K, 20, 1, NUM_CLASSES, False, GROUPS]  #net = DenseNet(K, 20, 1, NUM_CLASSES, False, GROUPS)

SHUFFLENET_BIG = [STAGES_REPEATS_BIG, STAGES_OUT_CHANNELS_BIG, NUM_CLASSES, GROUPS] #net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)
SHUFFLENET_SMALL = [STAGES_REPEATS_SMALL, STAGES_OUT_CHANNELS_SMALL, NUM_CLASSES, GROUPS] #net = ShuffleNetV2(stages_repeats, stages_out_channels, NUM_CLASSES, GROUPS)

#architectures = ["/resnet20/resnet20_bn", "/resnet20/resnet20_gn", "/densenet/densenet10", "/densenet/densenet20", "/shufflenetv2/shufflenetbig", "/shufflenetv2/shufflenetsmall"]

archs_dir = {}
archs_dir["/resnet20/resnet20_bn"] = (ResNet, RESNET20_BN_PARAMS)
archs_dir["/resnet20/resnet20_gn"] = (ResNet, RESNET20_GN_PARAMS)
archs_dir["/densenet/densenet10"] = (DenseNet, DENSENET10_PARAMS)
archs_dir["/densenet/densenet20"] = (DenseNet, DENSENET20_PARAMS)
archs_dir["/shufflenetv2/shufflenetbig"] = (ShuffleNetV2, SHUFFLENET_BIG)
archs_dir["/shufflenetv2/shufflenetsmall"] = (ShuffleNetV2, SHUFFLENET_SMALL)

# %% [markdown]
# ## Load dictionary of architectures
# "client_architectures.csv" contains entries of the form "client_id,architecture"
#
# In this cell, we create a dictionary "client_archs" having as key the id of the client and as value the network instantiated using the hyperparameters defined above. The network parameters are initialized with the parameters obtained after training on the public dataset (CIFAR10).

# %%
import csv
import torch.nn as nn
from fedmd.models_implementations.utils import load_model

filename ="fedmd/client/client_architectures.csv"
# this csv has records with attributes "client_id"(0,1,2,3,...) and "architecture" (the keys used in "archs_dir" above)

client_archs = {} #key=client_id, val=model instance

with open(filename,'r') as data:
  for line in csv.reader(data):
    if line[0] != 'client_id':
      client_id = line[0]
      architecture = line[1]
      
      net_class = archs_dir[architecture][0]
      params = archs_dir[architecture][1]

      # instantiate model for the client
      client_archs[client_id] = net_class(*params)

      # load parameters of best model on the public dataset (CIFAR10)

      data = load_model('fedmd/baselines_public_cifar10'+architecture+'/best_model.pth')
      weights = data["weights"]
      client_archs[client_id].load_state_dict(weights)

      # changing the last FC layer
      cifar100_fc = nn.Linear(in_features=client_archs[client_id].fc.in_features, out_features=100)
      client_archs[client_id].fc = cifar100_fc

print(len(client_archs))
# Out:
# 100

# %% [markdown]
# The next cell will create the directory "independent_train" and a subdirectory for each client where the checkpoints and the stats will be stored for each client

# %%
import os
if not os.path.isdir('independent_train'):
  PATH = os.getcwd() + '/independent_train'

  c_ids = [str(i) for i in range(100)]
  # !mkdir independent_train

  for c_id in c_ids:
    client_path = PATH + '/client' + c_id
    os.mkdir(client_path)

# %%
from fedmd.models_implementations.train_on_cifar import _training
from fedmd.client.private_dataloader import ClientPrivateDataset
from fedmd.data_utils import read_data_splits
from torchvision.datasets import CIFAR100
from torchvision import transforms

PATH = os.getcwd() + '/independent_train'

LR = 1e-1     
MOMENTUM = 0.9       
WEIGHT_DECAY = 1e-4  
#NUM_EPOCHS = 150
NUM_CLASSES = 100
GROUPS = 2
LAYERS = [3, 3, 3]

PRIVATE_TRAIN_DATA_DIR = os.path.join('.', 'fedmd', 'data', 'cifar100', 'data', 'train') # location of json files storing the data splits
PRIVATE_TEST_DATA_DIR = os.path.join('.', 'fedmd', 'data', 'cifar100', 'data', 'test')
ALPHA = 1000.00
#ALPHA = 0.00    # non-IID
#ALPHA = 0.50    # non-IID

BATCH_SIZE = 128
NUM_WORKERS = 1

client_ids, train_data, test_data = read_data_splits(PRIVATE_TRAIN_DATA_DIR, PRIVATE_TEST_DATA_DIR, ALPHA)
# train_clients: list of client ids 
# train_data: dictionary with key=client_id and value=(dictionary storing the data of the client)
# test_data: dictionary storing the data for validation. It is not a dictionary of dictionaries. It is used by all clients

eval_transform = transforms.Compose(
    [
        transforms.ToTensor(),  # Turn PIL Image to torch.Tensor
        transforms.Normalize(
            (0.485, 0.456, 0.406), (0.229, 0.224, 0.225)
        ),  # Normalizes tensor with mean and standard deviation
    ]
)

private_test_dataset = CIFAR100(root=".", train=True, transform=eval_transform, download=True)   # the same test dataset for all clients
private_test_dataloader = DataLoader(private_test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

private_train_dataloaders = {}
for cycle in range(4,10):
  c_ids = [str(i) for i in range(cycle*10, (cycle+1)*10)]
  for c_id in c_ids:
    client_path = PATH + '/client' + c_id# + '_' + str(ALPHA)

    private_train_dataset = ClientPrivateDataset(train_data[c_id], train=True)
    private_train_dataloaders[c_id] = DataLoader(private_train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)# , drop_last=True)

    num_epochs = 10 # in case we'll analyse ALPHA=0.50
    if ALPHA == 0.00:
      num_epochs = 5
    elif ALPHA == 1000.00:
      num_epochs = 30

    print()
    print(f"####################################### Beginning training on client{c_id} on it private data: ALPHA={ALPHA} ############################################")
    print()
    _training(net=client_archs[c_id], tr_set=private_train_dataloaders[c_id], val_set=private_test_dataloader, num_epochs=num_epochs, lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY,
              file_path=client_path)

    os.rename('independent_train/client'+c_id+'/best_model.pth', 'independent_train/client'+c_id+'/best_model_'+str(ALPHA)+'.pth')
    os.rename('independent_train/client'+c_id+'/checkpoint.pth', 'independent_train/client'+c_id+'/checkpoint_'+str(ALPHA)+'.pth')
    os.rename('independent_train/client'+c_id+'/stats.csv', 'independent_train/client'+c_id+'/stats_'+str(ALPHA)+'.csv')

  zip_name = f"/content/independent_train_{cycle*10}_{(cycle+1)*10}_ALPHA_{ALPHA}.zip"
  # !zip -r {zip_name} /content/independent_train/
  # !cp {zip_name} /content/drive/MyDrive/understanding_federated_learning_project/independent_train
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:01<00:00, 106110803.14it/s]
# Streaming output truncated to the last 5000 lines.
# Current Val Accuracy = 0.16308343989769822
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 2.034829616546631
# Current Val Accuracy = 0.1578484654731458
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 1.726812720298767
# Current Val Accuracy = 0.16825847186700768
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 1.6916913986206055
# Current Val Accuracy = 0.16861812659846548
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 1.601304531097412
# Current Val Accuracy = 0.16156489769820973
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 1.4701106548309326
# Current Val Accuracy = 0.15403212915601022
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 1.5155078172683716
# Current Val Accuracy = 0.17413283248081843
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 1.545712947845459
# Current Val Accuracy = 0.1698968989769821
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 1.343461036682129
# Current Val Accuracy = 0.1716951726342711
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 1.3253979682922363
# Current Val Accuracy = 0.16206441815856779
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 1.2977977991104126
# Current Val Accuracy = 0.1631633631713555
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 1.3088006973266602
# Current Val Accuracy = 0.16238411125319693
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 1.1908392906188965
# Current Val Accuracy = 0.14993606138107418
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 1.2869340181350708
# Current Val Accuracy = 0.147258631713555
# Max Validation Accuracy: 0.17413283248081843
#
# ####################################### Beginning training on client59 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.607253551483154
# Current Val Accuracy = 0.007492806905370844
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.585622787475586
# Current Val Accuracy = 0.008731617647058824
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.557053565979004
# Current Val Accuracy = 0.018402333759590793
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.519064903259277
# Current Val Accuracy = 0.027093989769820973
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.4717864990234375
# Current Val Accuracy = 0.030151054987212277
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.436748027801514
# Current Val Accuracy = 0.031130115089514066
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.376872539520264
# Current Val Accuracy = 0.029791400255754476
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.308850288391113
# Current Val Accuracy = 0.03312819693094629
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.251157760620117
# Current Val Accuracy = 0.039362212276214836
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.160323619842529
# Current Val Accuracy = 0.04455722506393862
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 4.0682830810546875
# Current Val Accuracy = 0.056885390025575445
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 3.9750051498413086
# Current Val Accuracy = 0.06905370843989769
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.8447492122650146
# Current Val Accuracy = 0.07460837595907928
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.741144895553589
# Current Val Accuracy = 0.08022298593350384
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.600184917449951
# Current Val Accuracy = 0.08168158567774936
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.530212879180908
# Current Val Accuracy = 0.08841512148337596
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.440810441970825
# Current Val Accuracy = 0.08589753836317135
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.2920613288879395
# Current Val Accuracy = 0.09474904092071611
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.2159392833709717
# Current Val Accuracy = 0.10471946930946291
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.1402270793914795
# Current Val Accuracy = 0.10056345907928389
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.1381192207336426
# Current Val Accuracy = 0.100383631713555
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 2.9936017990112305
# Current Val Accuracy = 0.1013826726342711
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 2.9626903533935547
# Current Val Accuracy = 0.10637787723785166
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 2.896587371826172
# Current Val Accuracy = 0.1128716432225064
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 2.8829853534698486
# Current Val Accuracy = 0.11403053069053709
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.787792682647705
# Current Val Accuracy = 0.11818654092071611
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.7131242752075195
# Current Val Accuracy = 0.11247202685421995
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.778770923614502
# Current Val Accuracy = 0.12064418158567775
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.689053535461426
# Current Val Accuracy = 0.1102741368286445
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.6010448932647705
# Current Val Accuracy = 0.11439018542199489
# Max Validation Accuracy: 0.12064418158567775
#   adding: content/independent_train/ (stored 0%)
#   adding: content/independent_train/client46/ (stored 0%)
#   adding: content/independent_train/client46/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client46/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client46/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client59/ (stored 0%)
#   adding: content/independent_train/client59/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client59/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client59/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client43/ (stored 0%)
#   adding: content/independent_train/client43/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client43/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client43/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client1/ (stored 0%)
#   adding: content/independent_train/client25/ (stored 0%)
#   adding: content/independent_train/client64/ (stored 0%)
#   adding: content/independent_train/client47/ (stored 0%)
#   adding: content/independent_train/client47/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client47/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client47/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client73/ (stored 0%)
#   adding: content/independent_train/client9/ (stored 0%)
#   adding: content/independent_train/client82/ (stored 0%)
#   adding: content/independent_train/client35/ (stored 0%)
#   adding: content/independent_train/client24/ (stored 0%)
#   adding: content/independent_train/client89/ (stored 0%)
#   adding: content/independent_train/client4/ (stored 0%)
#   adding: content/independent_train/client65/ (stored 0%)
#   adding: content/independent_train/client33/ (stored 0%)
#   adding: content/independent_train/client14/ (stored 0%)
#   adding: content/independent_train/client76/ (stored 0%)
#   adding: content/independent_train/client92/ (stored 0%)
#   adding: content/independent_train/client12/ (stored 0%)
#   adding: content/independent_train/client36/ (stored 0%)
#   adding: content/independent_train/client16/ (stored 0%)
#   adding: content/independent_train/client77/ (stored 0%)
#   adding: content/independent_train/client94/ (stored 0%)
#   adding: content/independent_train/client57/ (stored 0%)
#   adding: content/independent_train/client57/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client57/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client57/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client51/ (stored 0%)
#   adding: content/independent_train/client51/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client51/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client51/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client54/ (stored 0%)
#   adding: content/independent_train/client54/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client54/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client54/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client5/ (stored 0%)
#   adding: content/independent_train/client10/ (stored 0%)
#   adding: content/independent_train/client52/ (stored 0%)
#   adding: content/independent_train/client52/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client52/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client52/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client62/ (stored 0%)
#   adding: content/independent_train/client37/ (stored 0%)
#   adding: content/independent_train/client86/ (stored 0%)
#   adding: content/independent_train/client78/ (stored 0%)
#   adding: content/independent_train/client6/ (stored 0%)
#   adding: content/independent_train/client45/ (stored 0%)
#   adding: content/independent_train/client45/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client45/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client45/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client15/ (stored 0%)
#   adding: content/independent_train/client90/ (stored 0%)
#   adding: content/independent_train/client3/ (stored 0%)
#   adding: content/independent_train/client75/ (stored 0%)
#   adding: content/independent_train/client60/ (stored 0%)
#   adding: content/independent_train/client87/ (stored 0%)
#   adding: content/independent_train/client79/ (stored 0%)
#   adding: content/independent_train/client28/ (stored 0%)
#   adding: content/independent_train/client27/ (stored 0%)
#   adding: content/independent_train/client30/ (stored 0%)
#   adding: content/independent_train/client39/ (stored 0%)
#   adding: content/independent_train/client20/ (stored 0%)
#   adding: content/independent_train/client0/ (stored 0%)
#   adding: content/independent_train/client80/ (stored 0%)
#   adding: content/independent_train/client93/ (stored 0%)
#   adding: content/independent_train/client63/ (stored 0%)
#   adding: content/independent_train/client2/ (stored 0%)
#   adding: content/independent_train/client42/ (stored 0%)
#   adding: content/independent_train/client42/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client42/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client42/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client40/ (stored 0%)
#   adding: content/independent_train/client40/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client40/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client40/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client7/ (stored 0%)
#   adding: content/independent_train/client13/ (stored 0%)
#   adding: content/independent_train/client91/ (stored 0%)
#   adding: content/independent_train/client19/ (stored 0%)
#   adding: content/independent_train/client67/ (stored 0%)
#   adding: content/independent_train/client95/ (stored 0%)
#   adding: content/independent_train/client48/ (stored 0%)
#   adding: content/independent_train/client48/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client48/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client48/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client69/ (stored 0%)
#   adding: content/independent_train/client97/ (stored 0%)
#   adding: content/independent_train/client83/ (stored 0%)
#   adding: content/independent_train/client81/ (stored 0%)
#   adding: content/independent_train/client22/ (stored 0%)
#   adding: content/independent_train/client17/ (stored 0%)
#   adding: content/independent_train/client11/ (stored 0%)
#   adding: content/independent_train/client84/ (stored 0%)
#   adding: content/independent_train/client70/ (stored 0%)
#   adding: content/independent_train/client18/ (stored 0%)
#   adding: content/independent_train/client96/ (stored 0%)
#   adding: content/independent_train/client71/ (stored 0%)
#   adding: content/independent_train/client50/ (stored 0%)
#   adding: content/independent_train/client50/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client50/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client50/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client98/ (stored 0%)
#   adding: content/independent_train/client68/ (stored 0%)
#   adding: content/independent_train/client55/ (stored 0%)
#   adding: content/independent_train/client55/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client55/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client55/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client74/ (stored 0%)
#   adding: content/independent_train/client38/ (stored 0%)
#   adding: content/independent_train/client8/ (stored 0%)
#   adding: content/independent_train/client32/ (stored 0%)
#   adding: content/independent_train/client53/ (stored 0%)
#   adding: content/independent_train/client53/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client53/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client53/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client31/ (stored 0%)
#   adding: content/independent_train/client21/ (stored 0%)
#   adding: content/independent_train/client61/ (stored 0%)
#   adding: content/independent_train/client23/ (stored 0%)
#   adding: content/independent_train/client49/ (stored 0%)
#   adding: content/independent_train/client49/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client49/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client49/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client41/ (stored 0%)
#   adding: content/independent_train/client41/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client41/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client41/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client29/ (stored 0%)
#   adding: content/independent_train/client56/ (stored 0%)
#   adding: content/independent_train/client56/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client56/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client56/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client44/ (stored 0%)
#   adding: content/independent_train/client44/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client44/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client44/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client34/ (stored 0%)
#   adding: content/independent_train/client99/ (stored 0%)
#   adding: content/independent_train/client85/ (stored 0%)
#   adding: content/independent_train/client72/ (stored 0%)
#   adding: content/independent_train/client88/ (stored 0%)
#   adding: content/independent_train/client66/ (stored 0%)
#   adding: content/independent_train/client26/ (stored 0%)
#   adding: content/independent_train/client58/ (stored 0%)
#   adding: content/independent_train/client58/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client58/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client58/checkpoint_1000.0.pth (deflated 9%)
#
# ####################################### Beginning training on client60 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.612356185913086
# Current Val Accuracy = 0.007253037084398977
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.59323787689209
# Current Val Accuracy = 0.010889546035805626
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.571463584899902
# Current Val Accuracy = 0.019001758312020462
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.5430121421813965
# Current Val Accuracy = 0.02883232097186701
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.517434120178223
# Current Val Accuracy = 0.03408727621483376
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.477924346923828
# Current Val Accuracy = 0.037444053708439895
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.437735080718994
# Current Val Accuracy = 0.041440217391304345
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.383707046508789
# Current Val Accuracy = 0.04361812659846547
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.317896842956543
# Current Val Accuracy = 0.047874040920716114
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.255631923675537
# Current Val Accuracy = 0.051170875959079286
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 4.188745021820068
# Current Val Accuracy = 0.054088075447570334
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 4.088889122009277
# Current Val Accuracy = 0.05788443094629156
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.990375518798828
# Current Val Accuracy = 0.06603660485933503
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.8833675384521484
# Current Val Accuracy = 0.0716512148337596
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.792020559310913
# Current Val Accuracy = 0.07768542199488492
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.6935341358184814
# Current Val Accuracy = 0.08815537084398976
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.559688091278076
# Current Val Accuracy = 0.09143222506393862
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.445887327194214
# Current Val Accuracy = 0.09610773657289003
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.384570360183716
# Current Val Accuracy = 0.09598785166240409
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.2773525714874268
# Current Val Accuracy = 0.09854539641943734
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.2119061946868896
# Current Val Accuracy = 0.09355019181585678
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.1429309844970703
# Current Val Accuracy = 0.10577845268542199
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 3.0354371070861816
# Current Val Accuracy = 0.10499920076726342
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 2.9384403228759766
# Current Val Accuracy = 0.11498960997442455
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 2.8983893394470215
# Current Val Accuracy = 0.11069373401534527
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.8044614791870117
# Current Val Accuracy = 0.11229219948849105
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.7881526947021484
# Current Val Accuracy = 0.11421035805626599
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.7411155700683594
# Current Val Accuracy = 0.11562899616368287
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.725829601287842
# Current Val Accuracy = 0.1164681905370844
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.583390951156616
# Current Val Accuracy = 0.11826646419437341
# Max Validation Accuracy: 0.11826646419437341
#
# ####################################### Beginning training on client61 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.614027976989746
# Current Val Accuracy = 0.008391943734015346
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.587338924407959
# Current Val Accuracy = 0.01564498081841432
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.548990726470947
# Current Val Accuracy = 0.029791400255754476
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.503335475921631
# Current Val Accuracy = 0.03081042199488491
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.448444366455078
# Current Val Accuracy = 0.027613491048593352
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.383400917053223
# Current Val Accuracy = 0.02645460358056266
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.318813323974609
# Current Val Accuracy = 0.029251918158567775
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.24557638168335
# Current Val Accuracy = 0.04251918158567775
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.131820201873779
# Current Val Accuracy = 0.0738091432225064
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 3.9988694190979004
# Current Val Accuracy = 0.08018302429667519
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 3.8581011295318604
# Current Val Accuracy = 0.08695652173913043
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 3.684054374694824
# Current Val Accuracy = 0.08721627237851662
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.570028066635132
# Current Val Accuracy = 0.1052389705882353
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.389742374420166
# Current Val Accuracy = 0.10382033248081841
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.2887189388275146
# Current Val Accuracy = 0.09261109335038363
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.1522057056427
# Current Val Accuracy = 0.11514945652173914
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.004068374633789
# Current Val Accuracy = 0.10332081202046035
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 2.8413138389587402
# Current Val Accuracy = 0.11750719309462916
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 2.861215114593506
# Current Val Accuracy = 0.11716751918158567
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 2.7383289337158203
# Current Val Accuracy = 0.1327925191815857
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 2.65445613861084
# Current Val Accuracy = 0.10475943094629156
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 2.7117133140563965
# Current Val Accuracy = 0.13379156010230178
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 2.485663414001465
# Current Val Accuracy = 0.13574968030690537
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 2.5560243129730225
# Current Val Accuracy = 0.14160406010230178
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 2.434831380844116
# Current Val Accuracy = 0.1394661125319693
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.339656114578247
# Current Val Accuracy = 0.1433024296675192
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.189836263656616
# Current Val Accuracy = 0.14230338874680307
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.3568179607391357
# Current Val Accuracy = 0.13750799232736574
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.3394901752471924
# Current Val Accuracy = 0.12330163043478261
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.335481882095337
# Current Val Accuracy = 0.13185342071611253
# Max Validation Accuracy: 0.1433024296675192
#
# ####################################### Beginning training on client62 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.617569923400879
# Current Val Accuracy = 0.00639386189258312
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.592738151550293
# Current Val Accuracy = 0.014486093350383632
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.556454658508301
# Current Val Accuracy = 0.022398497442455242
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.513027191162109
# Current Val Accuracy = 0.032648657289002556
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.462472915649414
# Current Val Accuracy = 0.035266144501278775
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.40167236328125
# Current Val Accuracy = 0.03970188618925831
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.328709602355957
# Current Val Accuracy = 0.0445372442455243
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.2476701736450195
# Current Val Accuracy = 0.05051150895140665
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.145448684692383
# Current Val Accuracy = 0.05496723145780051
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.006250858306885
# Current Val Accuracy = 0.06863411125319693
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 3.856299877166748
# Current Val Accuracy = 0.07534766624040921
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 3.7172460556030273
# Current Val Accuracy = 0.08230099104859336
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.5678627490997314
# Current Val Accuracy = 0.08687659846547315
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.4374680519104004
# Current Val Accuracy = 0.09139226342710997
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.285132884979248
# Current Val Accuracy = 0.10445971867007672
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.183405876159668
# Current Val Accuracy = 0.10769661125319693
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.1054913997650146
# Current Val Accuracy = 0.10927509590792839
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.0388431549072266
# Current Val Accuracy = 0.11668797953964194
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 2.8696818351745605
# Current Val Accuracy = 0.12683823529411764
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 2.765669345855713
# Current Val Accuracy = 0.1277773337595908
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 2.71372389793396
# Current Val Accuracy = 0.11472985933503836
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 2.6769490242004395
# Current Val Accuracy = 0.12567934782608695
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 2.6237447261810303
# Current Val Accuracy = 0.1301350703324808
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 2.477637529373169
# Current Val Accuracy = 0.1390864769820972
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 2.35355281829834
# Current Val Accuracy = 0.13329203964194372
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.3581411838531494
# Current Val Accuracy = 0.13205322890025575
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.267794370651245
# Current Val Accuracy = 0.1329124040920716
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.2572264671325684
# Current Val Accuracy = 0.13475063938618925
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.2091732025146484
# Current Val Accuracy = 0.13421115728900257
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.0990777015686035
# Current Val Accuracy = 0.14356218030690537
# Max Validation Accuracy: 0.14356218030690537
#
# ####################################### Beginning training on client63 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.609838008880615
# Current Val Accuracy = 0.012228260869565218
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.595919609069824
# Current Val Accuracy = 0.01804267902813299
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.573563575744629
# Current Val Accuracy = 0.020820012787723784
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.545047760009766
# Current Val Accuracy = 0.02617487212276215
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.514941215515137
# Current Val Accuracy = 0.03125
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.475797176361084
# Current Val Accuracy = 0.032648657289002556
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.425567150115967
# Current Val Accuracy = 0.03300831202046036
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.374810218811035
# Current Val Accuracy = 0.034127237851662405
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.302212238311768
# Current Val Accuracy = 0.0358256074168798
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.238351345062256
# Current Val Accuracy = 0.035386029411764705
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 4.152230739593506
# Current Val Accuracy = 0.04078085038363171
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 4.079629898071289
# Current Val Accuracy = 0.04869325447570332
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 4.001957416534424
# Current Val Accuracy = 0.055167039641943735
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.9099597930908203
# Current Val Accuracy = 0.05776454603580563
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.8061158657073975
# Current Val Accuracy = 0.06002237851662404
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.723698377609253
# Current Val Accuracy = 0.06569693094629156
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.60292387008667
# Current Val Accuracy = 0.0708519820971867
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.5515480041503906
# Current Val Accuracy = 0.07496803069053709
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.4136996269226074
# Current Val Accuracy = 0.08148177749360613
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.3653628826141357
# Current Val Accuracy = 0.08821531329923274
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.318246603012085
# Current Val Accuracy = 0.09085278132992328
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.2623753547668457
# Current Val Accuracy = 0.08783567774936062
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 3.1316099166870117
# Current Val Accuracy = 0.09832560741687979
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 3.0255444049835205
# Current Val Accuracy = 0.09562819693094629
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 3.021178722381592
# Current Val Accuracy = 0.09996403452685422
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.971414566040039
# Current Val Accuracy = 0.09199168797953965
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.89713454246521
# Current Val Accuracy = 0.09912484015345269
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.796380043029785
# Current Val Accuracy = 0.10877557544757033
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.705557107925415
# Current Val Accuracy = 0.10817615089514067
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.6624367237091064
# Current Val Accuracy = 0.10769661125319693
# Max Validation Accuracy: 0.10877557544757033
#
# ####################################### Beginning training on client64 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.607611656188965
# Current Val Accuracy = 0.008292039641943734
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.591041564941406
# Current Val Accuracy = 0.014665920716112533
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.5741286277771
# Current Val Accuracy = 0.021719149616368286
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.538281440734863
# Current Val Accuracy = 0.02565537084398977
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.503452301025391
# Current Val Accuracy = 0.02725383631713555
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.45591402053833
# Current Val Accuracy = 0.030051150895140665
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.415131092071533
# Current Val Accuracy = 0.03204923273657289
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.348081588745117
# Current Val Accuracy = 0.03696451406649617
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.2886152267456055
# Current Val Accuracy = 0.04185981457800512
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.197587966918945
# Current Val Accuracy = 0.04809382992327366
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 4.117066383361816
# Current Val Accuracy = 0.05286924552429668
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 4.002987384796143
# Current Val Accuracy = 0.06002237851662404
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.9160566329956055
# Current Val Accuracy = 0.0676150895140665
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.8313183784484863
# Current Val Accuracy = 0.06971307544757033
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.707461357116699
# Current Val Accuracy = 0.07452845268542199
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.5870048999786377
# Current Val Accuracy = 0.08609734654731457
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.4762582778930664
# Current Val Accuracy = 0.08853500639386189
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.4048850536346436
# Current Val Accuracy = 0.08605738491048594
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.2949235439300537
# Current Val Accuracy = 0.08975383631713554
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.2129569053649902
# Current Val Accuracy = 0.10062340153452685
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.1547651290893555
# Current Val Accuracy = 0.10392023657289003
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.037224292755127
# Current Val Accuracy = 0.10445971867007672
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 2.962862730026245
# Current Val Accuracy = 0.10877557544757033
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 2.876777172088623
# Current Val Accuracy = 0.09700687340153452
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 2.8599181175231934
# Current Val Accuracy = 0.10985453964194374
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.771088123321533
# Current Val Accuracy = 0.11888586956521739
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.7143266201019287
# Current Val Accuracy = 0.10731697570332481
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.644615888595581
# Current Val Accuracy = 0.11079363810741688
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.6478688716888428
# Current Val Accuracy = 0.11580882352941177
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.558420181274414
# Current Val Accuracy = 0.1157488810741688
# Max Validation Accuracy: 0.11888586956521739
#
# ####################################### Beginning training on client65 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.607770919799805
# Current Val Accuracy = 0.013866687979539641
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.596271514892578
# Current Val Accuracy = 0.020380434782608696
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.5767364501953125
# Current Val Accuracy = 0.02725383631713555
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.551013946533203
# Current Val Accuracy = 0.0319693094629156
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.523430824279785
# Current Val Accuracy = 0.036245204603580564
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.486911296844482
# Current Val Accuracy = 0.03838315217391304
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.445980072021484
# Current Val Accuracy = 0.041660006393861894
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.391786575317383
# Current Val Accuracy = 0.04020140664961637
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.333242416381836
# Current Val Accuracy = 0.04201966112531969
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 4.275707244873047
# Current Val Accuracy = 0.04395780051150895
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 4.2050628662109375
# Current Val Accuracy = 0.04697490409207161
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 4.113152027130127
# Current Val Accuracy = 0.05065137468030691
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 4.050446510314941
# Current Val Accuracy = 0.05506713554987212
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.9462978839874268
# Current Val Accuracy = 0.06078164961636829
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.864978313446045
# Current Val Accuracy = 0.06695572250639387
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.7637462615966797
# Current Val Accuracy = 0.07003276854219949
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.696611166000366
# Current Val Accuracy = 0.07368925831202046
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.589263677597046
# Current Val Accuracy = 0.07366927749360613
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.4794437885284424
# Current Val Accuracy = 0.08290041560102301
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.4611315727233887
# Current Val Accuracy = 0.07950367647058823
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.36948823928833
# Current Val Accuracy = 0.08567774936061381
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.3328871726989746
# Current Val Accuracy = 0.08885469948849105
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 3.185521125793457
# Current Val Accuracy = 0.09031329923273658
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 3.1488423347473145
# Current Val Accuracy = 0.09261109335038363
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 3.0757148265838623
# Current Val Accuracy = 0.08843510230179027
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 3.12760591506958
# Current Val Accuracy = 0.08757592710997443
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 3.0584819316864014
# Current Val Accuracy = 0.10477941176470588
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.9688220024108887
# Current Val Accuracy = 0.09468909846547315
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.9441306591033936
# Current Val Accuracy = 0.10034367007672634
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.835981607437134
# Current Val Accuracy = 0.108196131713555
# Max Validation Accuracy: 0.108196131713555
#
# ####################################### Beginning training on client66 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.610731601715088
# Current Val Accuracy = 0.011269181585677749
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.596710681915283
# Current Val Accuracy = 0.01358695652173913
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.564777851104736
# Current Val Accuracy = 0.022218670076726343
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.525327682495117
# Current Val Accuracy = 0.032548753196930943
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.478117942810059
# Current Val Accuracy = 0.04110054347826087
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.410251617431641
# Current Val Accuracy = 0.04423753196930946
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.325847625732422
# Current Val Accuracy = 0.048213714833759594
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.237593650817871
# Current Val Accuracy = 0.051510549872122766
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.087352752685547
# Current Val Accuracy = 0.0616008631713555
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 3.9682679176330566
# Current Val Accuracy = 0.06935342071611253
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 3.8371775150299072
# Current Val Accuracy = 0.07610693734015345
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 3.7067456245422363
# Current Val Accuracy = 0.07724584398976982
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.6643543243408203
# Current Val Accuracy = 0.08030290920716113
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.6312737464904785
# Current Val Accuracy = 0.08156170076726342
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.529818058013916
# Current Val Accuracy = 0.0853980179028133
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.4896366596221924
# Current Val Accuracy = 0.09568813938618925
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.319350242614746
# Current Val Accuracy = 0.09592790920716113
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.2701597213745117
# Current Val Accuracy = 0.09844549232736573
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.3006181716918945
# Current Val Accuracy = 0.0986053388746803
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.2381982803344727
# Current Val Accuracy = 0.0933903452685422
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.1512491703033447
# Current Val Accuracy = 0.10032368925831202
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.1322178840637207
# Current Val Accuracy = 0.09900495524296675
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 3.041874647140503
# Current Val Accuracy = 0.10493925831202046
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 3.076244354248047
# Current Val Accuracy = 0.10104299872122763
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 3.0899124145507812
# Current Val Accuracy = 0.10346067774936062
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.9706039428710938
# Current Val Accuracy = 0.10543877877237852
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.8296029567718506
# Current Val Accuracy = 0.10905530690537084
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.7795050144195557
# Current Val Accuracy = 0.11604859335038363
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 3.0188052654266357
# Current Val Accuracy = 0.10599824168797954
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.7949609756469727
# Current Val Accuracy = 0.10917519181585678
# Max Validation Accuracy: 0.11604859335038363
#
# ####################################### Beginning training on client67 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.605433464050293
# Current Val Accuracy = 0.013287244245524297
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.581612586975098
# Current Val Accuracy = 0.018961796675191815
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.492297172546387
# Current Val Accuracy = 0.017603101023017903
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.415792942047119
# Current Val Accuracy = 0.020640185421994885
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.30765438079834
# Current Val Accuracy = 0.031909367007672634
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.174051284790039
# Current Val Accuracy = 0.05155051150895141
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.058372497558594
# Current Val Accuracy = 0.06777493606138107
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 3.829085111618042
# Current Val Accuracy = 0.08349984015345269
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 3.602111577987671
# Current Val Accuracy = 0.10052349744245524
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 3.4258229732513428
# Current Val Accuracy = 0.11586876598465473
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 3.130437135696411
# Current Val Accuracy = 0.12350143861892583
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 2.960275173187256
# Current Val Accuracy = 0.13421115728900257
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 2.730712652206421
# Current Val Accuracy = 0.1428628516624041
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 2.5452375411987305
# Current Val Accuracy = 0.14534047314578005
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 2.4097671508789062
# Current Val Accuracy = 0.1507752557544757
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 2.1766867637634277
# Current Val Accuracy = 0.16060581841432225
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 2.0774776935577393
# Current Val Accuracy = 0.15796835038363172
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 1.9675334692001343
# Current Val Accuracy = 0.16516144501278773
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 1.8439314365386963
# Current Val Accuracy = 0.16268382352941177
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 1.701303243637085
# Current Val Accuracy = 0.15988650895140666
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 1.7007805109024048
# Current Val Accuracy = 0.16284367007672634
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 1.5240058898925781
# Current Val Accuracy = 0.1703364769820972
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 1.5001834630966187
# Current Val Accuracy = 0.17621083759590792
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 1.408447265625
# Current Val Accuracy = 0.16885789641943735
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 1.4749035835266113
# Current Val Accuracy = 0.1690776854219949
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 1.3048151731491089
# Current Val Accuracy = 0.17005674552429667
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 1.246556043624878
# Current Val Accuracy = 0.1715353260869565
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 1.1558253765106201
# Current Val Accuracy = 0.17127557544757033
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 1.1892720460891724
# Current Val Accuracy = 0.16476182864450128
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 1.0351121425628662
# Current Val Accuracy = 0.16979699488491048
# Max Validation Accuracy: 0.17621083759590792
#
# ####################################### Beginning training on client68 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.605529308319092
# Current Val Accuracy = 0.014585997442455242
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.586780548095703
# Current Val Accuracy = 0.019281489769820973
# Starting epoch 3/30, LR = 0.1
# Current Avg Loss = 4.560519218444824
# Current Val Accuracy = 0.02369725063938619
# Starting epoch 4/30, LR = 0.1
# Current Avg Loss = 4.516304969787598
# Current Val Accuracy = 0.030770460358056265
# Starting epoch 5/30, LR = 0.1
# Current Avg Loss = 4.460084438323975
# Current Val Accuracy = 0.033387947570332484
# Starting epoch 6/30, LR = 0.1
# Current Avg Loss = 4.386758804321289
# Current Val Accuracy = 0.03650495524296675
# Starting epoch 7/30, LR = 0.1
# Current Avg Loss = 4.296507835388184
# Current Val Accuracy = 0.03894261508951407
# Starting epoch 8/30, LR = 0.1
# Current Avg Loss = 4.193957328796387
# Current Val Accuracy = 0.04599584398976982
# Starting epoch 9/30, LR = 0.1
# Current Avg Loss = 4.054889678955078
# Current Val Accuracy = 0.05586636828644501
# Starting epoch 10/30, LR = 0.1
# Current Avg Loss = 3.9193115234375
# Current Val Accuracy = 0.07456841432225064
# Starting epoch 11/30, LR = 0.1
# Current Avg Loss = 3.7866737842559814
# Current Val Accuracy = 0.0772258631713555
# Starting epoch 12/30, LR = 0.1
# Current Avg Loss = 3.740461826324463
# Current Val Accuracy = 0.07584718670076726
# Starting epoch 13/30, LR = 0.1
# Current Avg Loss = 3.6315855979919434
# Current Val Accuracy = 0.08661684782608696
# Starting epoch 14/30, LR = 0.1
# Current Avg Loss = 3.495830774307251
# Current Val Accuracy = 0.08835517902813299
# Starting epoch 15/30, LR = 0.1
# Current Avg Loss = 3.4820010662078857
# Current Val Accuracy = 0.09039322250639387
# Starting epoch 16/30, LR = 0.1
# Current Avg Loss = 3.3626720905303955
# Current Val Accuracy = 0.09408967391304347
# Starting epoch 17/30, LR = 0.1
# Current Avg Loss = 3.494143486022949
# Current Val Accuracy = 0.09380994245524296
# Starting epoch 18/30, LR = 0.1
# Current Avg Loss = 3.3041086196899414
# Current Val Accuracy = 0.08981377877237852
# Starting epoch 19/30, LR = 0.1
# Current Avg Loss = 3.2882728576660156
# Current Val Accuracy = 0.10212196291560102
# Starting epoch 20/30, LR = 0.1
# Current Avg Loss = 3.2122981548309326
# Current Val Accuracy = 0.10465952685421995
# Starting epoch 21/30, LR = 0.1
# Current Avg Loss = 3.2571539878845215
# Current Val Accuracy = 0.10745684143222506
# Starting epoch 22/30, LR = 0.1
# Current Avg Loss = 3.1475343704223633
# Current Val Accuracy = 0.10086317135549872
# Starting epoch 23/30, LR = 0.1
# Current Avg Loss = 3.114818572998047
# Current Val Accuracy = 0.10170236572890026
# Starting epoch 24/30, LR = 0.1
# Current Avg Loss = 3.032747507095337
# Current Val Accuracy = 0.11329124040920716
# Starting epoch 25/30, LR = 0.1
# Current Avg Loss = 3.0128180980682373
# Current Val Accuracy = 0.1105338874680307
# Starting epoch 26/30, LR = 0.1
# Current Avg Loss = 2.8973867893218994
# Current Val Accuracy = 0.10473945012787723
# Starting epoch 27/30, LR = 0.1
# Current Avg Loss = 2.943176507949829
# Current Val Accuracy = 0.11381074168797954
# Starting epoch 28/30, LR = 0.1
# Current Avg Loss = 2.9041342735290527
# Current Val Accuracy = 0.1166480179028133
# Starting epoch 29/30, LR = 0.1
# Current Avg Loss = 2.8914740085601807
# Current Val Accuracy = 0.11494964833759591
# Starting epoch 30/30, LR = 0.1
# Current Avg Loss = 2.7638697624206543
# Current Val Accuracy = 0.10773657289002557
# Max Validation Accuracy: 0.1166480179028133
#
# ####################################### Beginning training on client69 on it private data: ALPHA=1000.0 ############################################
#
# Starting epoch 1/30, LR = 0.1
# Current Avg Loss = 4.607636451721191
# Current Val Accuracy = 0.014446131713554987
# Starting epoch 2/30, LR = 0.1
# Current Avg Loss = 4.5900163650512695
# ...
#   adding: content/independent_train/client94/ (stored 0%)
#   adding: content/independent_train/client94/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client94/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client94/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client57/ (stored 0%)
#   adding: content/independent_train/client57/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client57/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client57/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client51/ (stored 0%)
#   adding: content/independent_train/client51/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client51/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client51/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client54/ (stored 0%)
#   adding: content/independent_train/client54/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client54/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client54/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client5/ (stored 0%)
#   adding: content/independent_train/client10/ (stored 0%)
#   adding: content/independent_train/client52/ (stored 0%)
#   adding: content/independent_train/client52/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client52/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client52/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client62/ (stored 0%)
#   adding: content/independent_train/client62/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client62/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client62/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client37/ (stored 0%)
#   adding: content/independent_train/client86/ (stored 0%)
#   adding: content/independent_train/client86/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client86/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client86/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client78/ (stored 0%)
#   adding: content/independent_train/client78/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client78/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client78/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client6/ (stored 0%)
#   adding: content/independent_train/client45/ (stored 0%)
#   adding: content/independent_train/client45/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client45/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client45/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client15/ (stored 0%)
#   adding: content/independent_train/client90/ (stored 0%)
#   adding: content/independent_train/client90/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client90/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client90/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client3/ (stored 0%)
#   adding: content/independent_train/client75/ (stored 0%)
#   adding: content/independent_train/client75/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client75/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client75/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client60/ (stored 0%)
#   adding: content/independent_train/client60/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client60/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client60/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client87/ (stored 0%)
#   adding: content/independent_train/client87/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client87/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client87/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client79/ (stored 0%)
#   adding: content/independent_train/client79/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client79/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client79/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client28/ (stored 0%)
#   adding: content/independent_train/client27/ (stored 0%)
#   adding: content/independent_train/client30/ (stored 0%)
#   adding: content/independent_train/client39/ (stored 0%)
#   adding: content/independent_train/client20/ (stored 0%)
#   adding: content/independent_train/client0/ (stored 0%)
#   adding: content/independent_train/client80/ (stored 0%)
#   adding: content/independent_train/client80/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client80/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client80/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client93/ (stored 0%)
#   adding: content/independent_train/client93/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client93/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client93/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client63/ (stored 0%)
#   adding: content/independent_train/client63/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client63/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client63/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client2/ (stored 0%)
#   adding: content/independent_train/client42/ (stored 0%)
#   adding: content/independent_train/client42/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client42/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client42/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client40/ (stored 0%)
#   adding: content/independent_train/client40/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client40/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client40/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client7/ (stored 0%)
#   adding: content/independent_train/client13/ (stored 0%)
#   adding: content/independent_train/client91/ (stored 0%)
#   adding: content/independent_train/client91/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client91/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client91/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client19/ (stored 0%)
#   adding: content/independent_train/client67/ (stored 0%)
#   adding: content/independent_train/client67/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client67/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client67/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client95/ (stored 0%)
#   adding: content/independent_train/client95/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client95/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client95/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client48/ (stored 0%)
#   adding: content/independent_train/client48/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client48/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client48/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client69/ (stored 0%)
#   adding: content/independent_train/client69/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client69/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client69/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client97/ (stored 0%)
#   adding: content/independent_train/client97/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client97/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client97/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client83/ (stored 0%)
#   adding: content/independent_train/client83/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client83/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client83/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client81/ (stored 0%)
#   adding: content/independent_train/client81/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client81/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client81/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client22/ (stored 0%)
#   adding: content/independent_train/client17/ (stored 0%)
#   adding: content/independent_train/client11/ (stored 0%)
#   adding: content/independent_train/client84/ (stored 0%)
#   adding: content/independent_train/client84/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client84/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client84/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client70/ (stored 0%)
#   adding: content/independent_train/client70/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client70/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client70/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client18/ (stored 0%)
#   adding: content/independent_train/client96/ (stored 0%)
#   adding: content/independent_train/client96/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client96/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client96/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client71/ (stored 0%)
#   adding: content/independent_train/client71/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client71/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client71/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client50/ (stored 0%)
#   adding: content/independent_train/client50/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client50/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client50/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client98/ (stored 0%)
#   adding: content/independent_train/client98/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client98/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client98/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client68/ (stored 0%)
#   adding: content/independent_train/client68/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client68/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client68/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client55/ (stored 0%)
#   adding: content/independent_train/client55/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client55/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client55/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client74/ (stored 0%)
#   adding: content/independent_train/client74/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client74/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client74/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client38/ (stored 0%)
#   adding: content/independent_train/client8/ (stored 0%)
#   adding: content/independent_train/client32/ (stored 0%)
#   adding: content/independent_train/client53/ (stored 0%)
#   adding: content/independent_train/client53/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client53/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client53/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client31/ (stored 0%)
#   adding: content/independent_train/client21/ (stored 0%)
#   adding: content/independent_train/client61/ (stored 0%)
#   adding: content/independent_train/client61/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client61/best_model_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client61/checkpoint_1000.0.pth (deflated 8%)
#   adding: content/independent_train/client23/ (stored 0%)
#   adding: content/independent_train/client49/ (stored 0%)
#   adding: content/independent_train/client49/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client49/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client49/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client41/ (stored 0%)
#   adding: content/independent_train/client41/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client41/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client41/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client29/ (stored 0%)
#   adding: content/independent_train/client56/ (stored 0%)
#   adding: content/independent_train/client56/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client56/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client56/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client44/ (stored 0%)
#   adding: content/independent_train/client44/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client44/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client44/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client34/ (stored 0%)
#   adding: content/independent_train/client99/ (stored 0%)
#   adding: content/independent_train/client99/stats_1000.0.csv (deflated 50%)
#   adding: content/independent_train/client99/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client99/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client85/ (stored 0%)
#   adding: content/independent_train/client85/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client85/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client85/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client72/ (stored 0%)
#   adding: content/independent_train/client72/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client72/best_model_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client72/checkpoint_1000.0.pth (deflated 12%)
#   adding: content/independent_train/client88/ (stored 0%)
#   adding: content/independent_train/client88/stats_1000.0.csv (deflated 48%)
#   adding: content/independent_train/client88/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client88/checkpoint_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client66/ (stored 0%)
#   adding: content/independent_train/client66/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client66/best_model_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client66/checkpoint_1000.0.pth (deflated 7%)
#   adding: content/independent_train/client26/ (stored 0%)
#   adding: content/independent_train/client58/ (stored 0%)
#   adding: content/independent_train/client58/stats_1000.0.csv (deflated 49%)
#   adding: content/independent_train/client58/best_model_1000.0.pth (deflated 9%)
#   adding: content/independent_train/client58/checkpoint_1000.0.pth (deflated 9%)

# %%
  zip_name = f"/content/independent_train_0_7_ALPHA_{ALPHA}.zip"
  # !zip -r {zip_name} /content/independent_train/
  # !cp {zip_name} /content/drive/MyDrive/understanding_federated_learning_project/independent_train
